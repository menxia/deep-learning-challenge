# %%
from __future__ import print_function

from keras import backend as K
K.set_image_dim_ordering('th') # ensure our dimension notation matches

from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.layers import Reshape
from keras.layers.core import Activation
from keras.layers.normalization import BatchNormalization
from keras.layers.convolutional import UpSampling2D
from keras.layers.convolutional import Convolution2D, AveragePooling2D
from keras.layers.core import Flatten
from keras.optimizers import SGD, Adam
from keras.datasets import mnist
from keras import utils
import numpy as np
from PIL import Image, ImageOps
import argparse
import math

import os
import os.path

import glob
# Out:
# Using TensorFlow backend.

# %%
def generator_model():
    model = Sequential()
    model.add(Dense(input_dim=100, output_dim=1024))
    model.add(Activation('tanh'))
    model.add(Dense(128*8*8))
    model.add(BatchNormalization())
    model.add(Activation('tanh'))
    model.add(Reshape((128, 8, 8), input_shape=(128*8*8,)))
    model.add(UpSampling2D(size=(4, 4)))
    model.add(Convolution2D(64, 5, 5, border_mode='same'))
    model.add(Activation('tanh'))
    model.add(UpSampling2D(size=(4, 4)))
    model.add(Convolution2D(1, 5, 5, border_mode='same'))
    model.add(Activation('tanh'))
    return model


def discriminator_model():
    model = Sequential()
    model.add(Convolution2D(
                        64, 5, 5,
                        border_mode='same',
                        input_shape=(1, 128, 128)))
    model.add(Activation('tanh'))
    model.add(AveragePooling2D(pool_size=(4, 4)))
    model.add(Convolution2D(128, 5, 5))
    model.add(Activation('tanh'))
    model.add(AveragePooling2D(pool_size=(2, 2)))
    model.add(Flatten())
    model.add(Dense(256))
    model.add(Activation('tanh'))
    model.add(Dense(1))
    model.add(Activation('sigmoid'))
    return model


def generator_containing_discriminator(generator, discriminator):
    model = Sequential()
    model.add(generator)
    discriminator.trainable = False
    model.add(discriminator)
    return model


def combine_images(generated_images):
    num = generated_images.shape[0]
    width = int(math.sqrt(num))
    height = int(math.ceil(float(num)/width))
    shape = generated_images.shape[2:]
    image = np.zeros((height*shape[0], width*shape[1]),
                     dtype=generated_images.dtype)
    for index, img in enumerate(generated_images):
        i = int(index/width)
        j = index % width
        image[i*shape[0]:(i+1)*shape[0], j*shape[1]:(j+1)*shape[1]] = \
            img[0, :, :]
    return image

# %%
model = generator_model()
print(model.summary())
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# dense_1 (Dense)                  (None, 1024)          103424      dense_input_1[0][0]
# ____________________________________________________________________________________________________
# activation_1 (Activation)        (None, 1024)          0           dense_1[0][0]
# ____________________________________________________________________________________________________
# dense_2 (Dense)                  (None, 8192)          8396800     activation_1[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_1 (BatchNorma (None, 8192)          32768       dense_2[0][0]
# ____________________________________________________________________________________________________
# activation_2 (Activation)        (None, 8192)          0           batchnormalization_1[0][0]
# ____________________________________________________________________________________________________
# reshape_1 (Reshape)              (None, 128, 8, 8)     0           activation_2[0][0]
# ____________________________________________________________________________________________________
# upsampling2d_1 (UpSampling2D)    (None, 128, 32, 32)   0           reshape_1[0][0]
# ____________________________________________________________________________________________________
# convolution2d_1 (Convolution2D)  (None, 64, 32, 32)    204864      upsampling2d_1[0][0]
# ____________________________________________________________________________________________________
# activation_3 (Activation)        (None, 64, 32, 32)    0           convolution2d_1[0][0]
# ____________________________________________________________________________________________________
# upsampling2d_2 (UpSampling2D)    (None, 64, 128, 128)  0           activation_3[0][0]
# ____________________________________________________________________________________________________
# convolution2d_2 (Convolution2D)  (None, 1, 128, 128)   1601        upsampling2d_2[0][0]
# ____________________________________________________________________________________________________
# activation_4 (Activation)        (None, 1, 128, 128)   0           convolution2d_2[0][0]
# ====================================================================================================
# Total params: 8,739,457
# Trainable params: 8,723,073
# Non-trainable params: 16,384
# ____________________________________________________________________________________________________
# None

# %%
def load_data(pixels=128, verbose=False):
    print("Loading data")
    X_train = []
    paths = glob.glob(os.path.normpath(os.getcwd() + '/logos/*.jpg'))
    for path in paths:
        if verbose: print(path)
        im = Image.open(path)
        im = ImageOps.fit(im, (pixels, pixels), Image.ANTIALIAS)
        im = ImageOps.grayscale(im)
        #im.show()
        im = np.asarray(im)
        X_train.append(im)
    print("Finished loading data")
    return np.array(X_train)

def train(epochs, BATCH_SIZE, weights=False):
    """
    :param epochs: Train for this many epochs
    :param BATCH_SIZE: Size of minibatch
    :param weights: If True, load weights from file, otherwise train the model from scratch. 
    Use this if you have already saved state of the network and want to train it further.
    """
    X_train = load_data()
    X_train = (X_train.astype(np.float32) - 127.5)/127.5
    X_train = X_train.reshape((X_train.shape[0], 1) + X_train.shape[1:])
    discriminator = discriminator_model()
    generator = generator_model()
    if weights:
        generator.load_weights('goodgenerator.h5')
        discriminator.load_weights('gooddiscriminator.h5')
    discriminator_on_generator = generator_containing_discriminator(generator, discriminator)
    d_optim = Adam(lr=0.0005)
    g_optim = Adam(lr=0.0005)
    generator.compile(loss='binary_crossentropy', optimizer=g_optim)
    discriminator_on_generator.compile(
        loss='binary_crossentropy', optimizer=g_optim)
    discriminator.trainable = True
    discriminator.compile(loss='binary_crossentropy', optimizer=d_optim)
    noise = np.zeros((BATCH_SIZE, 100))
    for epoch in range(epochs):
        print("Epoch is", epoch)
        print("Number of batches", int(X_train.shape[0]/BATCH_SIZE))
        for index in range(int(X_train.shape[0]/BATCH_SIZE)):
            for i in range(BATCH_SIZE):
                noise[i, :] = np.random.uniform(-1, 1, 100)
            image_batch = X_train[index*BATCH_SIZE:(index+1)*BATCH_SIZE]
            generated_images = generator.predict(noise, verbose=0)
            #print(generated_images.shape)
            if index % 20 == 0 and epoch % 10 == 0:
                image = combine_images(generated_images)
                image = image*127.5+127.5
                destpath = os.path.normpath(os.getcwd()+ "/logo-generated-images/"+str(epoch)+"_"+str(index)+".png")
                Image.fromarray(image.astype(np.uint8)).save(destpath)
            X = np.concatenate((image_batch, generated_images))
            y = [1] * BATCH_SIZE + [0] * BATCH_SIZE
            d_loss = discriminator.train_on_batch(X, y)
            print("batch %d d_loss : %f" % (index, d_loss))
            for i in range(BATCH_SIZE):
                noise[i, :] = np.random.uniform(-1, 1, 100)
            discriminator.trainable = False
            g_loss = discriminator_on_generator.train_on_batch(
                noise, [1] * BATCH_SIZE)
            discriminator.trainable = True
            print("batch %d g_loss : %f" % (index, g_loss))
            if epoch % 10 == 9:
                generator.save_weights('goodgenerator.h5', True)
                discriminator.save_weights('gooddiscriminator.h5', True)

def clean(image):
    for i in range(1, image.shape[0] - 1):
        for j in range(1, image.shape[1] - 1):
            if image[i][j] + image[i+1][j] + image[i][j+1] + image[i-1][j] + image[i][j-1] > 127 * 5:
                image[i][j] = 255
    return image
def generate(BATCH_SIZE):
    generator = generator_model()
    generator.compile(loss='binary_crossentropy', optimizer="SGD")
    generator.load_weights('goodgenerator.h5')
    noise = np.zeros((BATCH_SIZE, 100))
    a = np.random.uniform(-1, 1, 100)
    b = np.random.uniform(-1, 1, 100)
    grad = (b - a) / BATCH_SIZE
    for i in range(BATCH_SIZE):
        noise[i, :] = np.random.uniform(-1, 1, 100)
    generated_images = generator.predict(noise, verbose=1)
    #image = combine_images(generated_images)
    print(generated_images.shape)
    for image in generated_images:
        image = image[0]
        image = image*127.5+127.5
        Image.fromarray(image.astype(np.uint8)).save("dirty.png")
        Image.fromarray(image.astype(np.uint8)).show()
        clean(image)
        image = Image.fromarray(image.astype(np.uint8))
        image.show()        
        image.save("clean.png")


def get_args():
    parser = argparse.ArgumentParser()
    parser.add_argument("--mode", type=str)
    parser.add_argument("--batch_size", type=int, default=128)
    parser.add_argument("--nice", dest="nice", action="store_true")
    parser.set_defaults(nice=False)
    args = parser.parse_args()
    return args

# %%
train(400, 9, False)
# Out:
# Loading data
# Finished loading data
# Epoch is 0
# Number of batches 4
# batch 0 d_loss : 0.734620
# batch 0 g_loss : 0.986609
# batch 1 d_loss : 0.480342
# batch 1 g_loss : 1.206964
# batch 2 d_loss : 0.396672
# batch 2 g_loss : 1.016623
# batch 3 d_loss : 0.845709
# batch 3 g_loss : 3.237215
# Epoch is 1
# Number of batches 4
# batch 0 d_loss : 0.822382
# batch 0 g_loss : 4.172337
# batch 1 d_loss : 1.009075
# batch 1 g_loss : 4.313078
# batch 2 d_loss : 0.441265
# batch 2 g_loss : 4.437695
# batch 3 d_loss : 2.961848
# batch 3 g_loss : 5.285885
# Epoch is 2
# Number of batches 4
# batch 0 d_loss : 1.508882
# batch 0 g_loss : 4.405725
# batch 1 d_loss : 1.595437
# batch 1 g_loss : 8.957571
# batch 2 d_loss : 2.134950
# batch 2 g_loss : 7.532962
# batch 3 d_loss : 5.595119
# batch 3 g_loss : 5.417499
# Epoch is 3
# Number of batches 4
# batch 0 d_loss : 1.768750
# batch 0 g_loss : 8.890535
# batch 1 d_loss : 4.406469
# batch 1 g_loss : 6.711526
# batch 2 d_loss : 2.244407
# batch 2 g_loss : 3.954610
# batch 3 d_loss : 0.052719
# batch 3 g_loss : 5.135836
# Epoch is 4
# Number of batches 4
# batch 0 d_loss : 5.904184
# batch 0 g_loss : 3.760577
# batch 1 d_loss : 1.712869
# batch 1 g_loss : 5.123672
# batch 2 d_loss : 0.229076
# batch 2 g_loss : 5.830218
# batch 3 d_loss : 0.567303
# batch 3 g_loss : 5.646083
# Epoch is 5
# Number of batches 4
# batch 0 d_loss : 1.008635
# batch 0 g_loss : 7.507627
# batch 1 d_loss : 1.388763
# batch 1 g_loss : 6.908175
# batch 2 d_loss : 2.679540
# batch 2 g_loss : 4.567129
# batch 3 d_loss : 3.643476
# batch 3 g_loss : 6.150585
# Epoch is 6
# Number of batches 4
# batch 0 d_loss : 1.668166
# batch 0 g_loss : 6.471641
# batch 1 d_loss : 2.625285
# batch 1 g_loss : 4.110017
# batch 2 d_loss : 1.074772
# batch 2 g_loss : 1.980801
# batch 3 d_loss : 0.810609
# batch 3 g_loss : 2.577096
# Epoch is 7
# Number of batches 4
# batch 0 d_loss : 1.353783
# batch 0 g_loss : 4.261545
# batch 1 d_loss : 0.944780
# batch 1 g_loss : 3.525419
# batch 2 d_loss : 0.330668
# batch 2 g_loss : 2.561752
# batch 3 d_loss : 0.229641
# batch 3 g_loss : 2.621962
# Epoch is 8
# Number of batches 4
# batch 0 d_loss : 0.606202
# batch 0 g_loss : 4.395662
# batch 1 d_loss : 0.054554
# batch 1 g_loss : 3.295129
# batch 2 d_loss : 0.230944
# batch 2 g_loss : 4.422890
# batch 3 d_loss : 0.151407
# batch 3 g_loss : 4.247096
# Epoch is 9
# Number of batches 4
# batch 0 d_loss : 0.511426
# batch 0 g_loss : 5.730213
# batch 1 d_loss : 0.387472
# batch 1 g_loss : 5.820353
# batch 2 d_loss : 0.127796
# batch 2 g_loss : 5.147708
# batch 3 d_loss : 0.292991
# batch 3 g_loss : 5.774155
# Epoch is 10
# Number of batches 4
# batch 0 d_loss : 0.701998
# batch 0 g_loss : 6.075498
# batch 1 d_loss : 0.197656
# batch 1 g_loss : 6.551795
# batch 2 d_loss : 0.552230
# batch 2 g_loss : 5.992690
# batch 3 d_loss : 0.214609
# batch 3 g_loss : 6.121866
# Epoch is 11
# Number of batches 4
# batch 0 d_loss : 0.510061
# batch 0 g_loss : 5.128487
# batch 1 d_loss : 0.585930
# batch 1 g_loss : 5.629023
# batch 2 d_loss : 0.020392
# batch 2 g_loss : 4.549690
# batch 3 d_loss : 0.211534
# batch 3 g_loss : 5.877153
# Epoch is 12
# Number of batches 4
# batch 0 d_loss : 0.262198
# batch 0 g_loss : 5.812332
# batch 1 d_loss : 0.110051
# batch 1 g_loss : 5.751256
# batch 2 d_loss : 0.077894
# batch 2 g_loss : 5.140514
# batch 3 d_loss : 0.127356
# batch 3 g_loss : 3.164185
# Epoch is 13
# Number of batches 4
# batch 0 d_loss : 0.123152
# batch 0 g_loss : 6.080463
# batch 1 d_loss : 0.125532
# batch 1 g_loss : 5.740661
# batch 2 d_loss : 0.229657
# batch 2 g_loss : 5.358257
# batch 3 d_loss : 0.169317
# batch 3 g_loss : 6.090837
# Epoch is 14
# Number of batches 4
# batch 0 d_loss : 0.283698
# batch 0 g_loss : 5.717106
# batch 1 d_loss : 0.099062
# batch 1 g_loss : 5.351677
# batch 2 d_loss : 0.090383
# batch 2 g_loss : 5.247074
# batch 3 d_loss : 0.546725
# batch 3 g_loss : 5.274743
# Epoch is 15
# Number of batches 4
# batch 0 d_loss : 0.189052
# batch 0 g_loss : 5.454933
# batch 1 d_loss : 0.032208
# batch 1 g_loss : 5.836991
# batch 2 d_loss : 0.133735
# batch 2 g_loss : 5.010095
# batch 3 d_loss : 0.194394
# batch 3 g_loss : 5.744011
# Epoch is 16
# Number of batches 4
# batch 0 d_loss : 0.199192
# batch 0 g_loss : 5.153649
# batch 1 d_loss : 0.065570
# batch 1 g_loss : 6.472028
# batch 2 d_loss : 0.049274
# batch 2 g_loss : 5.841645
# batch 3 d_loss : 0.222622
# batch 3 g_loss : 5.892734
# Epoch is 17
# Number of batches 4
# batch 0 d_loss : 0.304309
# batch 0 g_loss : 5.198771
# batch 1 d_loss : 0.142625
# batch 1 g_loss : 4.664003
# batch 2 d_loss : 0.246354
# batch 2 g_loss : 4.176021
# batch 3 d_loss : 0.114034
# batch 3 g_loss : 5.181518
# Epoch is 18
# Number of batches 4
# batch 0 d_loss : 0.119957
# batch 0 g_loss : 5.714586
# batch 1 d_loss : 0.208106
# batch 1 g_loss : 6.457857
# batch 2 d_loss : 0.140418
# batch 2 g_loss : 6.067669
# batch 3 d_loss : 0.220631
# batch 3 g_loss : 6.835832
# Epoch is 19
# Number of batches 4
# batch 0 d_loss : 0.201835
# batch 0 g_loss : 5.225459
# batch 1 d_loss : 0.092954
# batch 1 g_loss : 5.776261
# batch 2 d_loss : 0.041932
# batch 2 g_loss : 6.235545
# batch 3 d_loss : 0.226626
# batch 3 g_loss : 4.978267
# Epoch is 20
# Number of batches 4
# batch 0 d_loss : 0.086250
# batch 0 g_loss : 6.241908
# batch 1 d_loss : 0.254117
# batch 1 g_loss : 5.755417
# batch 2 d_loss : 0.053933
# batch 2 g_loss : 6.043610
# batch 3 d_loss : 0.172042
# batch 3 g_loss : 5.475508
# Epoch is 21
# Number of batches 4
# batch 0 d_loss : 0.167403
# batch 0 g_loss : 6.084363
# batch 1 d_loss : 0.089398
# batch 1 g_loss : 4.845263
# batch 2 d_loss : 0.040529
# batch 2 g_loss : 5.307476
# batch 3 d_loss : 0.030529
# batch 3 g_loss : 4.104768
# Epoch is 22
# Number of batches 4
# batch 0 d_loss : 0.085456
# batch 0 g_loss : 3.767673
# batch 1 d_loss : 0.181756
# batch 1 g_loss : 5.260887
# batch 2 d_loss : 0.043640
# batch 2 g_loss : 5.276894
# batch 3 d_loss : 0.045603
# batch 3 g_loss : 5.175557
# Epoch is 23
# Number of batches 4
# batch 0 d_loss : 0.210366
# batch 0 g_loss : 5.898388
# batch 1 d_loss : 0.072507
# batch 1 g_loss : 5.595692
# batch 2 d_loss : 0.080651
# batch 2 g_loss : 4.716627
# batch 3 d_loss : 0.089612
# batch 3 g_loss : 5.942109
# Epoch is 24
# Number of batches 4
# batch 0 d_loss : 0.081711
# batch 0 g_loss : 4.659674
# batch 1 d_loss : 0.101122
# batch 1 g_loss : 4.742878
# batch 2 d_loss : 0.329373
# batch 2 g_loss : 5.268769
# batch 3 d_loss : 0.056878
# batch 3 g_loss : 5.667931
# Epoch is 25
# Number of batches 4
# batch 0 d_loss : 0.134644
# batch 0 g_loss : 4.763247
# batch 1 d_loss : 0.053891
# batch 1 g_loss : 5.478268
# batch 2 d_loss : 0.064270
# batch 2 g_loss : 5.366496
# batch 3 d_loss : 0.084026
# batch 3 g_loss : 4.976251
# Epoch is 26
# Number of batches 4
# batch 0 d_loss : 0.162615
# batch 0 g_loss : 5.354277
# batch 1 d_loss : 0.042140
# batch 1 g_loss : 5.908937
# batch 2 d_loss : 0.140008
# batch 2 g_loss : 5.559575
# batch 3 d_loss : 0.044098
# batch 3 g_loss : 6.003693
# Epoch is 27
# Number of batches 4
# batch 0 d_loss : 0.214886
# batch 0 g_loss : 6.076096
# batch 1 d_loss : 0.042226
# batch 1 g_loss : 6.033160
# batch 2 d_loss : 0.116220
# batch 2 g_loss : 6.354004
# batch 3 d_loss : 0.069947
# batch 3 g_loss : 6.169079
# Epoch is 28
# Number of batches 4
# batch 0 d_loss : 0.049246
# batch 0 g_loss : 5.305326
# batch 1 d_loss : 0.166081
# batch 1 g_loss : 6.904096
# batch 2 d_loss : 0.156408
# batch 2 g_loss : 5.399661
# batch 3 d_loss : 0.036119
# batch 3 g_loss : 5.725829
# Epoch is 29
# Number of batches 4
# batch 0 d_loss : 0.048377
# batch 0 g_loss : 6.016315
# batch 1 d_loss : 0.081336
# batch 1 g_loss : 6.983543
# batch 2 d_loss : 0.086653
# batch 2 g_loss : 6.074231
# batch 3 d_loss : 0.112713
# batch 3 g_loss : 6.208536
# Epoch is 30
# Number of batches 4
# batch 0 d_loss : 0.288921
# batch 0 g_loss : 6.572534
# batch 1 d_loss : 0.051949
# batch 1 g_loss : 6.578930
# batch 2 d_loss : 0.197138
# batch 2 g_loss : 6.239396
# batch 3 d_loss : 0.141290
# batch 3 g_loss : 5.972453
# Epoch is 31
# Number of batches 4
# batch 0 d_loss : 0.050332
# batch 0 g_loss : 6.171655
# batch 1 d_loss : 0.026540
# batch 1 g_loss : 5.442644
# batch 2 d_loss : 0.027600
# batch 2 g_loss : 5.316340
# batch 3 d_loss : 0.398687
# batch 3 g_loss : 7.022864
# Epoch is 32
# Number of batches 4
# batch 0 d_loss : 0.075930
# batch 0 g_loss : 5.988641
# batch 1 d_loss : 0.104096
# batch 1 g_loss : 6.131885
# batch 2 d_loss : 0.128349
# batch 2 g_loss : 6.461220
# batch 3 d_loss : 0.153495
# batch 3 g_loss : 6.029509
# Epoch is 33
# Number of batches 4
# batch 0 d_loss : 0.053944
# batch 0 g_loss : 6.010226
# batch 1 d_loss : 0.192682
# batch 1 g_loss : 5.241373
# batch 2 d_loss : 0.418637
# batch 2 g_loss : 6.308493
# batch 3 d_loss : 0.051754
# batch 3 g_loss : 5.879088
# Epoch is 34
# Number of batches 4
# batch 0 d_loss : 0.188440
# batch 0 g_loss : 6.598925
# batch 1 d_loss : 0.127501
# batch 1 g_loss : 6.657363
# batch 2 d_loss : 0.088441
# batch 2 g_loss : 6.455283
# batch 3 d_loss : 0.091156
# batch 3 g_loss : 5.676685
# Epoch is 35
# Number of batches 4
# batch 0 d_loss : 0.077668
# batch 0 g_loss : 6.337030
# batch 1 d_loss : 0.271892
# batch 1 g_loss : 5.495589
# batch 2 d_loss : 0.027772
# batch 2 g_loss : 5.154654
# batch 3 d_loss : 0.059885
# batch 3 g_loss : 5.714443
# Epoch is 36
# Number of batches 4
# batch 0 d_loss : 0.042478
# batch 0 g_loss : 6.423901
# batch 1 d_loss : 0.122534
# batch 1 g_loss : 6.054552
# batch 2 d_loss : 0.065800
# batch 2 g_loss : 5.845559
# batch 3 d_loss : 0.074318
# batch 3 g_loss : 6.617049
# Epoch is 37
# Number of batches 4
# batch 0 d_loss : 0.084050
# batch 0 g_loss : 6.145950
# batch 1 d_loss : 0.223669
# batch 1 g_loss : 5.220400
# batch 2 d_loss : 0.131211
# batch 2 g_loss : 6.355672
# batch 3 d_loss : 0.079202
# batch 3 g_loss : 6.105408
# Epoch is 38
# Number of batches 4
# batch 0 d_loss : 0.068226
# batch 0 g_loss : 5.341692
# batch 1 d_loss : 0.048709
# batch 1 g_loss : 5.909997
# batch 2 d_loss : 0.152128
# batch 2 g_loss : 6.468463
# batch 3 d_loss : 0.168970
# batch 3 g_loss : 5.734461
# Epoch is 39
# Number of batches 4
# batch 0 d_loss : 0.193174
# batch 0 g_loss : 5.026641
# batch 1 d_loss : 0.087585
# batch 1 g_loss : 6.586321
# batch 2 d_loss : 0.126016
# batch 2 g_loss : 5.431085
# batch 3 d_loss : 0.268939
# batch 3 g_loss : 6.278885
# Epoch is 40
# Number of batches 4
# batch 0 d_loss : 0.062175
# batch 0 g_loss : 6.111275
# batch 1 d_loss : 0.169794
# batch 1 g_loss : 6.259610
# batch 2 d_loss : 0.353216
# batch 2 g_loss : 6.440801
# batch 3 d_loss : 0.181836
# batch 3 g_loss : 6.158209
# Epoch is 41
# Number of batches 4
# batch 0 d_loss : 0.302346
# batch 0 g_loss : 6.324490
# batch 1 d_loss : 0.232502
# batch 1 g_loss : 6.333551
# batch 2 d_loss : 0.204151
# batch 2 g_loss : 6.415783
# batch 3 d_loss : 0.409826
# batch 3 g_loss : 7.092148
# Epoch is 42
# Number of batches 4
# batch 0 d_loss : 0.063827
# batch 0 g_loss : 5.986794
# batch 1 d_loss : 0.156320
# batch 1 g_loss : 5.389962
# batch 2 d_loss : 0.268700
# batch 2 g_loss : 6.958838
# batch 3 d_loss : 0.165867
# batch 3 g_loss : 6.777740
# Epoch is 43
# Number of batches 4
# batch 0 d_loss : 0.438778
# batch 0 g_loss : 5.792875
# batch 1 d_loss : 0.149293
# batch 1 g_loss : 6.566337
# batch 2 d_loss : 0.101353
# batch 2 g_loss : 6.643375
# batch 3 d_loss : 0.265186
# batch 3 g_loss : 7.348513
# Epoch is 44
# Number of batches 4
# batch 0 d_loss : 0.131600
# batch 0 g_loss : 6.456911
# batch 1 d_loss : 0.295583
# batch 1 g_loss : 6.827879
# batch 2 d_loss : 0.158652
# batch 2 g_loss : 6.703290
# batch 3 d_loss : 0.213715
# batch 3 g_loss : 7.672865
# Epoch is 45
# Number of batches 4
# batch 0 d_loss : 0.159977
# batch 0 g_loss : 8.266729
# batch 1 d_loss : 0.113905
# batch 1 g_loss : 7.398932
# batch 2 d_loss : 0.280762
# batch 2 g_loss : 7.537221
# batch 3 d_loss : 0.180119
# batch 3 g_loss : 7.499945
# Epoch is 46
# Number of batches 4
# batch 0 d_loss : 0.106922
# batch 0 g_loss : 7.086296
# batch 1 d_loss : 0.126491
# batch 1 g_loss : 6.924982
# batch 2 d_loss : 0.074325
# batch 2 g_loss : 5.788457
# batch 3 d_loss : 0.059150
# batch 3 g_loss : 6.816694
# Epoch is 47
# Number of batches 4
# batch 0 d_loss : 0.320384
# batch 0 g_loss : 7.654719
# batch 1 d_loss : 0.129651
# batch 1 g_loss : 7.930463
# batch 2 d_loss : 0.081686
# batch 2 g_loss : 7.120149
# batch 3 d_loss : 0.188856
# batch 3 g_loss : 7.085124
# Epoch is 48
# Number of batches 4
# batch 0 d_loss : 0.061587
# batch 0 g_loss : 6.691836
# batch 1 d_loss : 0.523123
# batch 1 g_loss : 5.942252
# batch 2 d_loss : 0.129780
# batch 2 g_loss : 6.224388
# batch 3 d_loss : 0.122085
# batch 3 g_loss : 5.579799
# Epoch is 49
# Number of batches 4
# batch 0 d_loss : 0.064292
# batch 0 g_loss : 6.370266
# batch 1 d_loss : 0.088676
# batch 1 g_loss : 6.120533
# batch 2 d_loss : 0.074327
# batch 2 g_loss : 6.679995
# batch 3 d_loss : 0.216533
# batch 3 g_loss : 6.784156
# Epoch is 50
# Number of batches 4
# batch 0 d_loss : 0.067831
# batch 0 g_loss : 5.050781
# batch 1 d_loss : 0.034538
# batch 1 g_loss : 6.225866
# batch 2 d_loss : 0.055085
# batch 2 g_loss : 5.279962
# batch 3 d_loss : 0.194508
# batch 3 g_loss : 5.329612
# Epoch is 51
# Number of batches 4
# batch 0 d_loss : 0.110445
# batch 0 g_loss : 5.949672
# batch 1 d_loss : 0.073531
# batch 1 g_loss : 6.494515
# batch 2 d_loss : 0.028315
# batch 2 g_loss : 6.401305
# batch 3 d_loss : 0.244579
# batch 3 g_loss : 7.057099
# Epoch is 52
# Number of batches 4
# batch 0 d_loss : 0.187058
# batch 0 g_loss : 5.827313
# batch 1 d_loss : 0.103719
# batch 1 g_loss : 6.865487
# batch 2 d_loss : 0.274803
# batch 2 g_loss : 6.420977
# batch 3 d_loss : 0.155450
# batch 3 g_loss : 5.502421
# Epoch is 53
# Number of batches 4
# batch 0 d_loss : 0.151514
# batch 0 g_loss : 5.727295
# batch 1 d_loss : 0.118709
# batch 1 g_loss : 6.140177
# batch 2 d_loss : 0.043922
# batch 2 g_loss : 5.453564
# batch 3 d_loss : 0.640403
# batch 3 g_loss : 4.723747
# Epoch is 54
# Number of batches 4
# batch 0 d_loss : 0.043154
# batch 0 g_loss : 5.135119
# batch 1 d_loss : 0.150824
# batch 1 g_loss : 6.425382
# batch 2 d_loss : 0.244434
# batch 2 g_loss : 7.788850
# batch 3 d_loss : 0.322882
# batch 3 g_loss : 5.996418
# Epoch is 55
# Number of batches 4
# batch 0 d_loss : 0.182604
# batch 0 g_loss : 5.225478
# batch 1 d_loss : 0.287933
# batch 1 g_loss : 6.544898
# batch 2 d_loss : 0.618037
# batch 2 g_loss : 5.440452
# batch 3 d_loss : 0.401725
# batch 3 g_loss : 5.917159
# Epoch is 56
# Number of batches 4
# batch 0 d_loss : 0.218088
# batch 0 g_loss : 5.633149
# batch 1 d_loss : 0.554384
# batch 1 g_loss : 5.646730
# batch 2 d_loss : 0.105198
# batch 2 g_loss : 6.043612
# batch 3 d_loss : 0.120638
# batch 3 g_loss : 5.645402
# Epoch is 57
# Number of batches 4
# batch 0 d_loss : 0.068887
# batch 0 g_loss : 5.604509
# batch 1 d_loss : 0.340258
# batch 1 g_loss : 6.103379
# batch 2 d_loss : 0.258550
# batch 2 g_loss : 5.607970
# batch 3 d_loss : 0.492855
# batch 3 g_loss : 6.933969
# Epoch is 58
# Number of batches 4
# batch 0 d_loss : 0.247820
# batch 0 g_loss : 6.829861
# batch 1 d_loss : 0.439415
# batch 1 g_loss : 5.573848
# batch 2 d_loss : 0.162244
# batch 2 g_loss : 4.991570
# batch 3 d_loss : 0.238359
# batch 3 g_loss : 4.976442
# Epoch is 59
# Number of batches 4
# batch 0 d_loss : 0.306189
# batch 0 g_loss : 4.774627
# batch 1 d_loss : 0.088883
# batch 1 g_loss : 4.961232
# batch 2 d_loss : 0.552726
# batch 2 g_loss : 5.324104
# batch 3 d_loss : 0.383535
# batch 3 g_loss : 6.375406
# Epoch is 60
# Number of batches 4
# batch 0 d_loss : 0.309010
# batch 0 g_loss : 5.770203
# batch 1 d_loss : 0.369383
# batch 1 g_loss : 5.521797
# batch 2 d_loss : 0.344767
# batch 2 g_loss : 5.041190
# batch 3 d_loss : 0.302140
# batch 3 g_loss : 4.422843
# Epoch is 61
# Number of batches 4
# batch 0 d_loss : 0.472971
# batch 0 g_loss : 4.993815
# batch 1 d_loss : 0.136082
# batch 1 g_loss : 4.813137
# batch 2 d_loss : 0.485438
# batch 2 g_loss : 4.592349
# batch 3 d_loss : 0.128043
# batch 3 g_loss : 5.279323
# Epoch is 62
# Number of batches 4
# batch 0 d_loss : 0.374265
# batch 0 g_loss : 4.178215
# batch 1 d_loss : 0.158639
# batch 1 g_loss : 6.583172
# batch 2 d_loss : 0.352720
# batch 2 g_loss : 5.461579
# batch 3 d_loss : 0.449123
# batch 3 g_loss : 5.209418
# Epoch is 63
# Number of batches 4
# batch 0 d_loss : 0.296594
# batch 0 g_loss : 5.117078
# batch 1 d_loss : 0.255998
# batch 1 g_loss : 4.391597
# batch 2 d_loss : 0.303443
# batch 2 g_loss : 5.421517
# batch 3 d_loss : 0.534255
# batch 3 g_loss : 5.357370
# Epoch is 64
# Number of batches 4
# batch 0 d_loss : 0.229952
# batch 0 g_loss : 4.359393
# batch 1 d_loss : 0.095646
# batch 1 g_loss : 4.750266
# batch 2 d_loss : 0.125362
# batch 2 g_loss : 4.839632
# batch 3 d_loss : 0.264411
# batch 3 g_loss : 4.916750
# Epoch is 65
# Number of batches 4
# batch 0 d_loss : 0.139707
# batch 0 g_loss : 5.019481
# batch 1 d_loss : 0.145450
# batch 1 g_loss : 4.113651
# batch 2 d_loss : 0.071789
# batch 2 g_loss : 3.610342
# batch 3 d_loss : 0.241227
# batch 3 g_loss : 4.566846
# Epoch is 66
# Number of batches 4
# batch 0 d_loss : 0.094956
# batch 0 g_loss : 4.179121
# batch 1 d_loss : 0.130558
# batch 1 g_loss : 4.254444
# batch 2 d_loss : 0.024269
# batch 2 g_loss : 4.013714
# batch 3 d_loss : 0.204208
# batch 3 g_loss : 4.599588
# Epoch is 67
# Number of batches 4
# batch 0 d_loss : 0.106014
# batch 0 g_loss : 4.014429
# batch 1 d_loss : 0.159376
# batch 1 g_loss : 4.229207
# batch 2 d_loss : 0.095444
# batch 2 g_loss : 4.838962
# batch 3 d_loss : 0.140256
# batch 3 g_loss : 4.292640
# Epoch is 68
# Number of batches 4
# batch 0 d_loss : 0.070098
# batch 0 g_loss : 4.512444
# batch 1 d_loss : 0.246355
# batch 1 g_loss : 4.658296
# batch 2 d_loss : 0.147431
# batch 2 g_loss : 4.867652
# batch 3 d_loss : 0.166900
# batch 3 g_loss : 4.166985
# Epoch is 69
# Number of batches 4
# batch 0 d_loss : 0.086838
# batch 0 g_loss : 4.936023
# batch 1 d_loss : 0.137428
# batch 1 g_loss : 5.691503
# batch 2 d_loss : 0.088733
# batch 2 g_loss : 4.798540
# batch 3 d_loss : 0.353842
# batch 3 g_loss : 4.857876
# Epoch is 70
# Number of batches 4
# batch 0 d_loss : 0.103376
# batch 0 g_loss : 3.796575
# batch 1 d_loss : 0.129080
# batch 1 g_loss : 5.194685
# batch 2 d_loss : 0.084931
# batch 2 g_loss : 5.853680
# batch 3 d_loss : 0.177560
# batch 3 g_loss : 4.784864
# Epoch is 71
# Number of batches 4
# batch 0 d_loss : 0.144962
# batch 0 g_loss : 5.361494
# batch 1 d_loss : 0.116733
# batch 1 g_loss : 4.894382
# batch 2 d_loss : 0.095810
# batch 2 g_loss : 5.670053
# batch 3 d_loss : 0.150091
# batch 3 g_loss : 5.169990
# Epoch is 72
# Number of batches 4
# batch 0 d_loss : 0.090997
# batch 0 g_loss : 5.777138
# batch 1 d_loss : 0.113215
# batch 1 g_loss : 5.390883
# batch 2 d_loss : 0.306529
# batch 2 g_loss : 6.143204
# batch 3 d_loss : 0.182048
# batch 3 g_loss : 5.894985
# Epoch is 73
# Number of batches 4
# batch 0 d_loss : 0.118169
# batch 0 g_loss : 6.356953
# batch 1 d_loss : 0.309768
# batch 1 g_loss : 4.776415
# batch 2 d_loss : 0.125887
# batch 2 g_loss : 6.252523
# batch 3 d_loss : 0.314259
# batch 3 g_loss : 5.023264
# Epoch is 74
# Number of batches 4
# batch 0 d_loss : 0.335147
# batch 0 g_loss : 5.685201
# batch 1 d_loss : 0.125891
# batch 1 g_loss : 5.865484
# batch 2 d_loss : 0.260668
# batch 2 g_loss : 6.175618
# batch 3 d_loss : 0.310048
# batch 3 g_loss : 5.646874
# Epoch is 75
# Number of batches 4
# batch 0 d_loss : 0.112517
# batch 0 g_loss : 4.431311
# batch 1 d_loss : 0.297987
# batch 1 g_loss : 4.867009
# batch 2 d_loss : 0.648702
# batch 2 g_loss : 5.567063
# batch 3 d_loss : 0.540684
# batch 3 g_loss : 6.561021
# Epoch is 76
# Number of batches 4
# batch 0 d_loss : 0.479139
# batch 0 g_loss : 6.803814
# batch 1 d_loss : 0.355143
# batch 1 g_loss : 5.443945
# batch 2 d_loss : 0.592277
# batch 2 g_loss : 5.499030
# batch 3 d_loss : 0.046396
# batch 3 g_loss : 5.302897
# Epoch is 77
# Number of batches 4
# batch 0 d_loss : 0.883987
# batch 0 g_loss : 5.925494
# batch 1 d_loss : 0.745899
# batch 1 g_loss : 6.277643
# batch 2 d_loss : 0.705232
# batch 2 g_loss : 6.811583
# batch 3 d_loss : 0.411744
# batch 3 g_loss : 6.615239
# Epoch is 78
# Number of batches 4
# batch 0 d_loss : 0.368949
# batch 0 g_loss : 5.641238
# batch 1 d_loss : 0.320180
# batch 1 g_loss : 5.944399
# batch 2 d_loss : 0.356419
# batch 2 g_loss : 5.947221
# batch 3 d_loss : 0.669783
# batch 3 g_loss : 4.737895
# Epoch is 79
# Number of batches 4
# batch 0 d_loss : 0.256354
# batch 0 g_loss : 5.743798
# batch 1 d_loss : 0.064761
# batch 1 g_loss : 5.935355
# batch 2 d_loss : 0.124503
# batch 2 g_loss : 4.920133
# batch 3 d_loss : 0.122828
# batch 3 g_loss : 4.708255
# Epoch is 80
# Number of batches 4
# batch 0 d_loss : 0.130653
# batch 0 g_loss : 5.317839
# batch 1 d_loss : 0.309106
# batch 1 g_loss : 5.403695
# batch 2 d_loss : 0.120915
# batch 2 g_loss : 6.221726
# batch 3 d_loss : 0.266702
# batch 3 g_loss : 6.371630
# Epoch is 81
# Number of batches 4
# batch 0 d_loss : 0.181275
# batch 0 g_loss : 5.631225
# batch 1 d_loss : 0.097117
# batch 1 g_loss : 5.210721
# batch 2 d_loss : 0.083909
# batch 2 g_loss : 4.750279
# batch 3 d_loss : 0.205507
# batch 3 g_loss : 5.854660
# Epoch is 82
# Number of batches 4
# batch 0 d_loss : 0.114886
# batch 0 g_loss : 5.365329
# batch 1 d_loss : 0.132027
# batch 1 g_loss : 5.249665
# batch 2 d_loss : 0.018064
# batch 2 g_loss : 4.687947
# batch 3 d_loss : 0.124007
# batch 3 g_loss : 5.142905
# Epoch is 83
# Number of batches 4
# batch 0 d_loss : 0.077977
# batch 0 g_loss : 5.273336
# batch 1 d_loss : 0.128677
# batch 1 g_loss : 5.770666
# batch 2 d_loss : 0.201450
# batch 2 g_loss : 4.948817
# batch 3 d_loss : 0.310828
# batch 3 g_loss : 5.215264
# Epoch is 84
# Number of batches 4
# batch 0 d_loss : 0.437140
# batch 0 g_loss : 5.340368
# batch 1 d_loss : 0.390707
# batch 1 g_loss : 5.690178
# batch 2 d_loss : 0.133194
# batch 2 g_loss : 4.630110
# batch 3 d_loss : 0.445472
# batch 3 g_loss : 5.581667
# Epoch is 85
# Number of batches 4
# batch 0 d_loss : 0.293429
# batch 0 g_loss : 4.536487
# batch 1 d_loss : 0.108950
# batch 1 g_loss : 5.736396
# batch 2 d_loss : 0.189423
# batch 2 g_loss : 5.315801
# batch 3 d_loss : 0.227136
# batch 3 g_loss : 4.720561
# Epoch is 86
# Number of batches 4
# batch 0 d_loss : 0.242632
# batch 0 g_loss : 4.502020
# batch 1 d_loss : 0.594720
# batch 1 g_loss : 6.242939
# batch 2 d_loss : 0.282218
# batch 2 g_loss : 5.771358
# batch 3 d_loss : 0.536745
# batch 3 g_loss : 5.026533
# Epoch is 87
# Number of batches 4
# batch 0 d_loss : 0.300149
# batch 0 g_loss : 4.877904
# batch 1 d_loss : 0.305329
# batch 1 g_loss : 5.144838
# batch 2 d_loss : 0.823297
# batch 2 g_loss : 4.667370
# batch 3 d_loss : 0.148851
# batch 3 g_loss : 5.700399
# Epoch is 88
# Number of batches 4
# batch 0 d_loss : 0.450339
# batch 0 g_loss : 6.067370
# batch 1 d_loss : 0.451661
# batch 1 g_loss : 4.813190
# batch 2 d_loss : 0.402894
# batch 2 g_loss : 5.335900
# batch 3 d_loss : 0.403009
# batch 3 g_loss : 4.679504
# Epoch is 89
# Number of batches 4
# batch 0 d_loss : 0.230660
# batch 0 g_loss : 5.142550
# batch 1 d_loss : 0.472825
# batch 1 g_loss : 5.595144
# batch 2 d_loss : 0.588032
# batch 2 g_loss : 5.980240
# batch 3 d_loss : 0.398496
# batch 3 g_loss : 6.184157
# Epoch is 90
# Number of batches 4
# batch 0 d_loss : 0.140528
# batch 0 g_loss : 5.642444
# batch 1 d_loss : 0.280730
# batch 1 g_loss : 5.420342
# batch 2 d_loss : 0.309623
# batch 2 g_loss : 5.404777
# batch 3 d_loss : 0.449164
# batch 3 g_loss : 4.618991
# Epoch is 91
# Number of batches 4
# batch 0 d_loss : 0.102649
# batch 0 g_loss : 5.336501
# batch 1 d_loss : 0.093627
# batch 1 g_loss : 5.136593
# batch 2 d_loss : 0.158847
# batch 2 g_loss : 4.866517
# batch 3 d_loss : 0.248586
# batch 3 g_loss : 4.197348
# Epoch is 92
# Number of batches 4
# batch 0 d_loss : 0.221333
# batch 0 g_loss : 5.426292
# batch 1 d_loss : 0.092978
# batch 1 g_loss : 6.708507
# batch 2 d_loss : 0.078323
# batch 2 g_loss : 4.974662
# batch 3 d_loss : 0.534814
# batch 3 g_loss : 3.869324
# Epoch is 93
# Number of batches 4
# batch 0 d_loss : 0.341792
# batch 0 g_loss : 5.455932
# batch 1 d_loss : 0.100333
# batch 1 g_loss : 4.801083
# batch 2 d_loss : 0.130705
# batch 2 g_loss : 5.777078
# batch 3 d_loss : 0.390175
# batch 3 g_loss : 4.901518
# Epoch is 94
# Number of batches 4
# batch 0 d_loss : 0.125838
# batch 0 g_loss : 4.702993
# batch 1 d_loss : 0.161442
# batch 1 g_loss : 4.753525
# batch 2 d_loss : 0.104037
# batch 2 g_loss : 4.527434
# batch 3 d_loss : 0.263936
# batch 3 g_loss : 5.560715
# Epoch is 95
# Number of batches 4
# batch 0 d_loss : 0.179157
# batch 0 g_loss : 5.751617
# batch 1 d_loss : 0.264092
# batch 1 g_loss : 5.833983
# batch 2 d_loss : 0.322470
# batch 2 g_loss : 4.730268
# batch 3 d_loss : 0.184645
# batch 3 g_loss : 4.910115
# Epoch is 96
# Number of batches 4
# batch 0 d_loss : 0.084400
# batch 0 g_loss : 5.737455
# batch 1 d_loss : 0.028713
# batch 1 g_loss : 4.358338
# batch 2 d_loss : 0.278058
# batch 2 g_loss : 4.825692
# batch 3 d_loss : 0.223628
# batch 3 g_loss : 5.060404
# Epoch is 97
# Number of batches 4
# batch 0 d_loss : 0.314321
# batch 0 g_loss : 5.213676
# batch 1 d_loss : 0.252444
# batch 1 g_loss : 4.579655
# batch 2 d_loss : 0.115981
# batch 2 g_loss : 5.222636
# batch 3 d_loss : 0.487094
# batch 3 g_loss : 6.044577
# Epoch is 98
# Number of batches 4
# batch 0 d_loss : 0.359106
# batch 0 g_loss : 4.941739
# batch 1 d_loss : 0.385012
# batch 1 g_loss : 5.504803
# batch 2 d_loss : 0.331787
# batch 2 g_loss : 5.237858
# batch 3 d_loss : 0.200855
# batch 3 g_loss : 4.655628
# Epoch is 99
# Number of batches 4
# batch 0 d_loss : 0.212851
# batch 0 g_loss : 3.333245
# batch 1 d_loss : 0.508979
# batch 1 g_loss : 4.208982
# batch 2 d_loss : 0.467522
# batch 2 g_loss : 4.007489
# batch 3 d_loss : 0.175847
# batch 3 g_loss : 3.441003
# Epoch is 100
# Number of batches 4
# batch 0 d_loss : 0.172318
# batch 0 g_loss : 3.109913
# batch 1 d_loss : 0.137350
# batch 1 g_loss : 3.997999
# batch 2 d_loss : 0.312367
# batch 2 g_loss : 4.259132
# batch 3 d_loss : 0.141397
# batch 3 g_loss : 4.374767
# Epoch is 101
# Number of batches 4
# batch 0 d_loss : 0.140990
# batch 0 g_loss : 3.854776
# batch 1 d_loss : 0.302031
# batch 1 g_loss : 3.470324
# batch 2 d_loss : 0.552238
# batch 2 g_loss : 3.746868
# batch 3 d_loss : 0.060840
# batch 3 g_loss : 2.693855
# Epoch is 102
# Number of batches 4
# batch 0 d_loss : 0.198065
# batch 0 g_loss : 3.903218
# batch 1 d_loss : 0.065762
# batch 1 g_loss : 3.516523
# batch 2 d_loss : 0.049571
# batch 2 g_loss : 3.597711
# batch 3 d_loss : 0.294810
# batch 3 g_loss : 4.336177
# Epoch is 103
# Number of batches 4
# batch 0 d_loss : 0.129829
# batch 0 g_loss : 3.624712
# batch 1 d_loss : 0.101470
# batch 1 g_loss : 3.739597
# batch 2 d_loss : 0.159571
# batch 2 g_loss : 4.892585
# batch 3 d_loss : 0.149222
# batch 3 g_loss : 4.518837
# Epoch is 104
# Number of batches 4
# batch 0 d_loss : 0.151632
# batch 0 g_loss : 4.867239
# batch 1 d_loss : 0.091006
# batch 1 g_loss : 4.733024
# batch 2 d_loss : 0.336736
# batch 2 g_loss : 4.930959
# batch 3 d_loss : 0.177502
# batch 3 g_loss : 4.825839
# Epoch is 105
# Number of batches 4
# batch 0 d_loss : 0.102281
# batch 0 g_loss : 4.935727
# batch 1 d_loss : 0.337666
# batch 1 g_loss : 4.979327
# batch 2 d_loss : 0.174826
# batch 2 g_loss : 5.193584
# batch 3 d_loss : 0.294391
# batch 3 g_loss : 5.630346
# Epoch is 106
# Number of batches 4
# batch 0 d_loss : 0.263770
# batch 0 g_loss : 6.109262
# batch 1 d_loss : 0.196806
# batch 1 g_loss : 5.105536
# batch 2 d_loss : 0.114425
# batch 2 g_loss : 5.291538
# batch 3 d_loss : 0.174781
# batch 3 g_loss : 5.315683
# Epoch is 107
# Number of batches 4
# batch 0 d_loss : 0.497581
# batch 0 g_loss : 5.607779
# batch 1 d_loss : 0.372321
# batch 1 g_loss : 5.391697
# batch 2 d_loss : 0.325544
# batch 2 g_loss : 5.904611
# batch 3 d_loss : 0.235826
# batch 3 g_loss : 6.357471
# Epoch is 108
# Number of batches 4
# batch 0 d_loss : 0.373333
# batch 0 g_loss : 5.753177
# batch 1 d_loss : 0.358631
# batch 1 g_loss : 5.413317
# batch 2 d_loss : 0.278409
# batch 2 g_loss : 5.743204
# batch 3 d_loss : 0.171504
# batch 3 g_loss : 4.213485
# Epoch is 109
# Number of batches 4
# batch 0 d_loss : 0.477885
# batch 0 g_loss : 4.958219
# batch 1 d_loss : 0.111604
# batch 1 g_loss : 5.376462
# batch 2 d_loss : 0.068981
# batch 2 g_loss : 5.447770
# batch 3 d_loss : 0.204638
# batch 3 g_loss : 4.529615
# Epoch is 110
# Number of batches 4
# batch 0 d_loss : 0.098759
# batch 0 g_loss : 4.483511
# batch 1 d_loss : 0.223179
# batch 1 g_loss : 5.131000
# batch 2 d_loss : 0.283761
# batch 2 g_loss : 6.562071
# batch 3 d_loss : 0.273253
# batch 3 g_loss : 6.024603
# Epoch is 111
# Number of batches 4
# batch 0 d_loss : 0.421063
# batch 0 g_loss : 5.974221
# batch 1 d_loss : 0.333989
# batch 1 g_loss : 5.369112
# batch 2 d_loss : 0.224317
# batch 2 g_loss : 4.498182
# batch 3 d_loss : 0.149380
# batch 3 g_loss : 5.247205
# Epoch is 112
# Number of batches 4
# batch 0 d_loss : 0.513456
# batch 0 g_loss : 4.647254
# batch 1 d_loss : 0.332926
# batch 1 g_loss : 4.852315
# batch 2 d_loss : 0.065139
# batch 2 g_loss : 5.046794
# batch 3 d_loss : 0.231486
# batch 3 g_loss : 5.521524
# Epoch is 113
# Number of batches 4
# batch 0 d_loss : 0.271294
# batch 0 g_loss : 4.614731
# batch 1 d_loss : 0.209565
# batch 1 g_loss : 5.770789
# batch 2 d_loss : 0.068988
# batch 2 g_loss : 5.862676
# batch 3 d_loss : 0.443284
# batch 3 g_loss : 4.948425
# Epoch is 114
# Number of batches 4
# batch 0 d_loss : 0.186104
# batch 0 g_loss : 5.184634
# batch 1 d_loss : 0.520673
# batch 1 g_loss : 4.972660
# batch 2 d_loss : 0.113770
# batch 2 g_loss : 5.982934
# batch 3 d_loss : 0.371897
# batch 3 g_loss : 5.585934
# Epoch is 115
# Number of batches 4
# batch 0 d_loss : 0.215798
# batch 0 g_loss : 6.418066
# batch 1 d_loss : 0.332396
# batch 1 g_loss : 6.066405
# batch 2 d_loss : 0.063808
# batch 2 g_loss : 5.208842
# batch 3 d_loss : 0.254050
# batch 3 g_loss : 4.709954
# Epoch is 116
# Number of batches 4
# batch 0 d_loss : 0.325416
# batch 0 g_loss : 3.853962
# batch 1 d_loss : 0.519759
# batch 1 g_loss : 5.166589
# batch 2 d_loss : 0.176224
# batch 2 g_loss : 5.683856
# batch 3 d_loss : 0.295713
# batch 3 g_loss : 5.861183
# Epoch is 117
# Number of batches 4
# batch 0 d_loss : 0.147512
# batch 0 g_loss : 4.138803
# batch 1 d_loss : 0.086514
# batch 1 g_loss : 4.671070
# batch 2 d_loss : 0.290289
# batch 2 g_loss : 3.949444
# batch 3 d_loss : 0.403084
# batch 3 g_loss : 4.410624
# Epoch is 118
# Number of batches 4
# batch 0 d_loss : 0.175763
# batch 0 g_loss : 5.902935
# batch 1 d_loss : 0.135094
# batch 1 g_loss : 4.415966
# batch 2 d_loss : 0.269515
# batch 2 g_loss : 6.206958
# batch 3 d_loss : 0.718026
# batch 3 g_loss : 5.571382
# Epoch is 119
# Number of batches 4
# batch 0 d_loss : 0.248364
# batch 0 g_loss : 5.454906
# batch 1 d_loss : 0.267705
# batch 1 g_loss : 5.443844
# batch 2 d_loss : 0.404771
# batch 2 g_loss : 5.483134
# batch 3 d_loss : 0.388495
# batch 3 g_loss : 5.475997
# Epoch is 120
# Number of batches 4
# batch 0 d_loss : 0.243431
# batch 0 g_loss : 5.703115
# batch 1 d_loss : 0.228716
# batch 1 g_loss : 6.124568
# batch 2 d_loss : 0.236965
# batch 2 g_loss : 4.903313
# batch 3 d_loss : 0.260679
# batch 3 g_loss : 5.967484
# Epoch is 121
# Number of batches 4
# batch 0 d_loss : 0.071442
# batch 0 g_loss : 5.032802
# batch 1 d_loss : 0.470688
# batch 1 g_loss : 3.911727
# batch 2 d_loss : 0.367659
# batch 2 g_loss : 5.839142
# batch 3 d_loss : 0.872025
# batch 3 g_loss : 5.151399
# Epoch is 122
# Number of batches 4
# batch 0 d_loss : 0.467108
# batch 0 g_loss : 5.317539
# batch 1 d_loss : 0.530530
# batch 1 g_loss : 5.839002
# batch 2 d_loss : 1.106975
# batch 2 g_loss : 4.925652
# batch 3 d_loss : 0.709317
# batch 3 g_loss : 4.567263
# Epoch is 123
# Number of batches 4
# batch 0 d_loss : 0.814222
# batch 0 g_loss : 4.078511
# batch 1 d_loss : 0.687851
# batch 1 g_loss : 4.312797
# batch 2 d_loss : 0.295804
# batch 2 g_loss : 3.769072
# batch 3 d_loss : 0.328290
# batch 3 g_loss : 4.554225
# Epoch is 124
# Number of batches 4
# batch 0 d_loss : 0.119426
# batch 0 g_loss : 3.672403
# batch 1 d_loss : 0.272717
# batch 1 g_loss : 3.910385
# batch 2 d_loss : 0.357340
# batch 2 g_loss : 3.398104
# batch 3 d_loss : 0.321393
# batch 3 g_loss : 3.491961
# Epoch is 125
# Number of batches 4
# batch 0 d_loss : 0.398260
# batch 0 g_loss : 3.632691
# batch 1 d_loss : 0.236602
# batch 1 g_loss : 4.059666
# batch 2 d_loss : 0.215220
# batch 2 g_loss : 4.119103
# batch 3 d_loss : 0.335212
# batch 3 g_loss : 3.363886
# Epoch is 126
# Number of batches 4
# batch 0 d_loss : 0.221672
# batch 0 g_loss : 3.747238
# batch 1 d_loss : 0.166733
# batch 1 g_loss : 3.626299
# batch 2 d_loss : 0.142746
# batch 2 g_loss : 3.903791
# batch 3 d_loss : 0.160374
# batch 3 g_loss : 3.152896
# Epoch is 127
# Number of batches 4
# batch 0 d_loss : 0.123023
# batch 0 g_loss : 4.262582
# batch 1 d_loss : 0.108537
# batch 1 g_loss : 3.799580
# batch 2 d_loss : 0.088254
# batch 2 g_loss : 4.449389
# batch 3 d_loss : 0.089045
# batch 3 g_loss : 4.044373
# Epoch is 128
# Number of batches 4
# batch 0 d_loss : 0.051184
# batch 0 g_loss : 4.936223
# batch 1 d_loss : 0.025118
# batch 1 g_loss : 4.652116
# batch 2 d_loss : 0.054330
# batch 2 g_loss : 4.768992
# batch 3 d_loss : 0.157392
# batch 3 g_loss : 3.591808
# Epoch is 129
# Number of batches 4
# batch 0 d_loss : 0.145232
# batch 0 g_loss : 4.449605
# batch 1 d_loss : 0.062394
# batch 1 g_loss : 5.311377
# batch 2 d_loss : 0.075245
# batch 2 g_loss : 4.275240
# batch 3 d_loss : 0.102552
# batch 3 g_loss : 5.185007
# Epoch is 130
# Number of batches 4
# batch 0 d_loss : 0.034134
# batch 0 g_loss : 4.885446
# batch 1 d_loss : 0.026966
# batch 1 g_loss : 4.595213
# batch 2 d_loss : 0.114402
# batch 2 g_loss : 4.964767
# batch 3 d_loss : 0.065098
# batch 3 g_loss : 4.665894
# Epoch is 131
# Number of batches 4
# batch 0 d_loss : 0.080551
# batch 0 g_loss : 5.519499
# batch 1 d_loss : 0.029617
# batch 1 g_loss : 4.138583
# batch 2 d_loss : 0.300976
# batch 2 g_loss : 5.098977
# batch 3 d_loss : 0.133374
# batch 3 g_loss : 5.862191
# Epoch is 132
# Number of batches 4
# batch 0 d_loss : 0.069379
# batch 0 g_loss : 5.959098
# batch 1 d_loss : 0.057472
# batch 1 g_loss : 5.476736
# batch 2 d_loss : 0.118267
# batch 2 g_loss : 4.789828
# batch 3 d_loss : 0.093713
# batch 3 g_loss : 4.943447
# Epoch is 133
# Number of batches 4
# batch 0 d_loss : 0.154482
# batch 0 g_loss : 4.516456
# batch 1 d_loss : 0.046035
# batch 1 g_loss : 5.211022
# batch 2 d_loss : 0.059296
# batch 2 g_loss : 5.931189
# batch 3 d_loss : 0.265006
# batch 3 g_loss : 4.209721
# Epoch is 134
# Number of batches 4
# batch 0 d_loss : 0.085251
# batch 0 g_loss : 5.280814
# batch 1 d_loss : 0.116960
# batch 1 g_loss : 4.905346
# batch 2 d_loss : 0.145316
# batch 2 g_loss : 4.912839
# batch 3 d_loss : 0.683381
# batch 3 g_loss : 5.185978
# Epoch is 135
# Number of batches 4
# batch 0 d_loss : 0.134205
# batch 0 g_loss : 4.549201
# batch 1 d_loss : 0.166726
# batch 1 g_loss : 4.754675
# batch 2 d_loss : 0.276667
# batch 2 g_loss : 4.247453
# batch 3 d_loss : 0.165799
# batch 3 g_loss : 4.652985
# Epoch is 136
# Number of batches 4
# batch 0 d_loss : 0.491387
# batch 0 g_loss : 5.053303
# batch 1 d_loss : 0.328824
# batch 1 g_loss : 5.649959
# batch 2 d_loss : 0.554379
# batch 2 g_loss : 5.603571
# batch 3 d_loss : 0.571478
# batch 3 g_loss : 5.373580
# Epoch is 137
# Number of batches 4
# batch 0 d_loss : 0.755112
# batch 0 g_loss : 5.680291
# batch 1 d_loss : 0.443602
# batch 1 g_loss : 4.916886
# batch 2 d_loss : 0.613681
# batch 2 g_loss : 5.865974
# batch 3 d_loss : 0.995416
# batch 3 g_loss : 5.722144
# Epoch is 138
# Number of batches 4
# batch 0 d_loss : 0.481518
# batch 0 g_loss : 5.523569
# batch 1 d_loss : 0.186104
# batch 1 g_loss : 5.801683
# batch 2 d_loss : 0.357709
# batch 2 g_loss : 5.036458
# batch 3 d_loss : 0.337721
# batch 3 g_loss : 3.732292
# Epoch is 139
# Number of batches 4
# batch 0 d_loss : 0.919151
# batch 0 g_loss : 4.814816
# batch 1 d_loss : 0.411940
# batch 1 g_loss : 5.084671
# batch 2 d_loss : 0.676349
# batch 2 g_loss : 5.511067
# batch 3 d_loss : 0.397968
# batch 3 g_loss : 4.127562
# Epoch is 140
# Number of batches 4
# batch 0 d_loss : 0.284765
# batch 0 g_loss : 4.634126
# batch 1 d_loss : 0.416303
# batch 1 g_loss : 3.981725
# batch 2 d_loss : 0.770087
# batch 2 g_loss : 3.134759
# batch 3 d_loss : 0.648516
# batch 3 g_loss : 4.814005
# Epoch is 141
# Number of batches 4
# batch 0 d_loss : 0.465870
# batch 0 g_loss : 4.635995
# batch 1 d_loss : 0.162006
# batch 1 g_loss : 5.109262
# batch 2 d_loss : 0.240450
# batch 2 g_loss : 5.121104
# batch 3 d_loss : 0.305367
# batch 3 g_loss : 3.344872
# Epoch is 142
# Number of batches 4
# batch 0 d_loss : 0.280173
# batch 0 g_loss : 3.856590
# batch 1 d_loss : 0.089971
# batch 1 g_loss : 3.414220
# batch 2 d_loss : 0.379739
# batch 2 g_loss : 3.506515
# batch 3 d_loss : 0.255119
# batch 3 g_loss : 3.694405
# Epoch is 143
# Number of batches 4
# batch 0 d_loss : 0.219915
# batch 0 g_loss : 3.168489
# batch 1 d_loss : 0.145435
# batch 1 g_loss : 3.617719
# batch 2 d_loss : 0.184228
# batch 2 g_loss : 3.197802
# batch 3 d_loss : 0.130562
# batch 3 g_loss : 3.154153
# Epoch is 144
# Number of batches 4
# batch 0 d_loss : 0.427330
# batch 0 g_loss : 3.309983
# batch 1 d_loss : 0.182198
# batch 1 g_loss : 3.781760
# batch 2 d_loss : 0.268307
# batch 2 g_loss : 3.234164
# batch 3 d_loss : 0.125804
# batch 3 g_loss : 3.596872
# Epoch is 145
# Number of batches 4
# batch 0 d_loss : 0.131698
# batch 0 g_loss : 4.039976
# batch 1 d_loss : 0.130836
# batch 1 g_loss : 3.775945
# batch 2 d_loss : 0.028009
# batch 2 g_loss : 3.307678
# batch 3 d_loss : 0.029501
# batch 3 g_loss : 3.559382
# Epoch is 146
# Number of batches 4
# batch 0 d_loss : 0.238680
# batch 0 g_loss : 4.015841
# batch 1 d_loss : 0.089687
# batch 1 g_loss : 4.042009
# batch 2 d_loss : 0.171486
# batch 2 g_loss : 4.215835
# batch 3 d_loss : 0.101555
# batch 3 g_loss : 4.163932
# Epoch is 147
# Number of batches 4
# batch 0 d_loss : 0.106480
# batch 0 g_loss : 4.803844
# batch 1 d_loss : 0.082750
# batch 1 g_loss : 4.307381
# batch 2 d_loss : 0.114142
# batch 2 g_loss : 4.427818
# batch 3 d_loss : 0.161276
# batch 3 g_loss : 4.280711
# Epoch is 148
# Number of batches 4
# batch 0 d_loss : 0.233186
# batch 0 g_loss : 4.026385
# batch 1 d_loss : 0.085685
# batch 1 g_loss : 4.311141
# batch 2 d_loss : 0.193227
# batch 2 g_loss : 4.856018
# batch 3 d_loss : 0.306479
# batch 3 g_loss : 4.269531
# Epoch is 149
# Number of batches 4
# batch 0 d_loss : 0.121445
# batch 0 g_loss : 4.068290
# batch 1 d_loss : 0.028329
# batch 1 g_loss : 4.743654
# batch 2 d_loss : 0.054349
# batch 2 g_loss : 4.447542
# batch 3 d_loss : 0.290275
# batch 3 g_loss : 5.048010
# Epoch is 150
# Number of batches 4
# batch 0 d_loss : 0.104169
# batch 0 g_loss : 5.010734
# batch 1 d_loss : 0.171190
# batch 1 g_loss : 4.800673
# batch 2 d_loss : 0.343653
# batch 2 g_loss : 4.460505
# batch 3 d_loss : 0.237637
# batch 3 g_loss : 4.976936
# Epoch is 151
# Number of batches 4
# batch 0 d_loss : 0.194834
# batch 0 g_loss : 4.553694
# batch 1 d_loss : 0.148885
# batch 1 g_loss : 4.401730
# batch 2 d_loss : 0.175832
# batch 2 g_loss : 4.604782
# batch 3 d_loss : 0.644702
# batch 3 g_loss : 4.680566
# Epoch is 152
# Number of batches 4
# batch 0 d_loss : 0.144883
# batch 0 g_loss : 4.567702
# batch 1 d_loss : 0.064673
# batch 1 g_loss : 4.776276
# batch 2 d_loss : 0.345705
# batch 2 g_loss : 5.063820
# batch 3 d_loss : 0.330826
# batch 3 g_loss : 4.634626
# Epoch is 153
# Number of batches 4
# batch 0 d_loss : 0.234123
# batch 0 g_loss : 4.748314
# batch 1 d_loss : 0.201043
# batch 1 g_loss : 4.405488
# batch 2 d_loss : 0.468319
# batch 2 g_loss : 4.019588
# batch 3 d_loss : 0.357722
# batch 3 g_loss : 4.588365
# Epoch is 154
# Number of batches 4
# batch 0 d_loss : 0.102607
# batch 0 g_loss : 5.526304
# batch 1 d_loss : 0.110285
# batch 1 g_loss : 5.110811
# batch 2 d_loss : 0.210750
# batch 2 g_loss : 4.786136
# batch 3 d_loss : 0.376891
# batch 3 g_loss : 5.146912
# Epoch is 155
# Number of batches 4
# batch 0 d_loss : 0.301738
# batch 0 g_loss : 5.021206
# batch 1 d_loss : 0.169682
# batch 1 g_loss : 4.108948
# batch 2 d_loss : 0.194207
# batch 2 g_loss : 4.349061
# batch 3 d_loss : 0.183484
# batch 3 g_loss : 4.379580
# Epoch is 156
# Number of batches 4
# batch 0 d_loss : 0.443121
# batch 0 g_loss : 5.643380
# batch 1 d_loss : 0.134926
# batch 1 g_loss : 5.092042
# batch 2 d_loss : 0.230283
# batch 2 g_loss : 5.596363
# batch 3 d_loss : 0.220323
# batch 3 g_loss : 5.202238
# Epoch is 157
# Number of batches 4
# batch 0 d_loss : 0.155819
# batch 0 g_loss : 4.468922
# batch 1 d_loss : 0.056825
# batch 1 g_loss : 3.783473
# batch 2 d_loss : 0.281654
# batch 2 g_loss : 3.356102
# batch 3 d_loss : 0.489299
# batch 3 g_loss : 4.937406
# Epoch is 158
# Number of batches 4
# batch 0 d_loss : 0.077867
# batch 0 g_loss : 5.306501
# batch 1 d_loss : 0.086580
# batch 1 g_loss : 4.415861
# batch 2 d_loss : 0.157458
# batch 2 g_loss : 5.166579
# batch 3 d_loss : 0.313028
# batch 3 g_loss : 4.901599
# Epoch is 159
# Number of batches 4
# batch 0 d_loss : 0.208946
# batch 0 g_loss : 5.504833
# batch 1 d_loss : 0.206524
# batch 1 g_loss : 5.152088
# batch 2 d_loss : 0.376304
# batch 2 g_loss : 4.970898
# batch 3 d_loss : 0.262012
# batch 3 g_loss : 5.318475
# Epoch is 160
# Number of batches 4
# batch 0 d_loss : 0.182003
# batch 0 g_loss : 5.145644
# batch 1 d_loss : 0.496922
# batch 1 g_loss : 4.404861
# batch 2 d_loss : 0.242832
# batch 2 g_loss : 5.608500
# batch 3 d_loss : 0.419389
# batch 3 g_loss : 5.370872
# Epoch is 161
# Number of batches 4
# batch 0 d_loss : 0.686406
# batch 0 g_loss : 5.772391
# batch 1 d_loss : 0.319363
# batch 1 g_loss : 5.799788
# batch 2 d_loss : 0.318767
# batch 2 g_loss : 4.494734
# batch 3 d_loss : 0.503691
# batch 3 g_loss : 4.329168
# Epoch is 162
# Number of batches 4
# batch 0 d_loss : 0.138775
# batch 0 g_loss : 5.019243
# batch 1 d_loss : 0.063091
# batch 1 g_loss : 4.195129
# batch 2 d_loss : 0.270331
# batch 2 g_loss : 4.284913
# batch 3 d_loss : 0.127196
# batch 3 g_loss : 4.425492
# Epoch is 163
# Number of batches 4
# batch 0 d_loss : 0.052336
# batch 0 g_loss : 4.732257
# batch 1 d_loss : 0.450431
# batch 1 g_loss : 3.607306
# batch 2 d_loss : 0.488942
# batch 2 g_loss : 5.223851
# batch 3 d_loss : 0.551433
# batch 3 g_loss : 6.095371
# Epoch is 164
# Number of batches 4
# batch 0 d_loss : 0.429673
# batch 0 g_loss : 5.398232
# batch 1 d_loss : 0.456620
# batch 1 g_loss : 5.336762
# batch 2 d_loss : 0.294197
# batch 2 g_loss : 3.991806
# batch 3 d_loss : 0.217147
# batch 3 g_loss : 3.383674
# Epoch is 165
# Number of batches 4
# batch 0 d_loss : 0.114755
# batch 0 g_loss : 4.665653
# batch 1 d_loss : 0.455703
# batch 1 g_loss : 4.754142
# batch 2 d_loss : 0.170237
# batch 2 g_loss : 3.516704
# batch 3 d_loss : 0.679419
# batch 3 g_loss : 3.512365
# Epoch is 166
# Number of batches 4
# batch 0 d_loss : 0.435477
# batch 0 g_loss : 4.120348
# batch 1 d_loss : 0.419804
# batch 1 g_loss : 5.211217
# batch 2 d_loss : 0.572063
# batch 2 g_loss : 4.392348
# batch 3 d_loss : 0.377524
# batch 3 g_loss : 4.488860
# Epoch is 167
# Number of batches 4
# batch 0 d_loss : 0.564915
# batch 0 g_loss : 5.287961
# batch 1 d_loss : 0.188962
# batch 1 g_loss : 3.932009
# batch 2 d_loss : 0.510789
# batch 2 g_loss : 3.966145
# batch 3 d_loss : 0.307531
# batch 3 g_loss : 4.090143
# Epoch is 168
# Number of batches 4
# batch 0 d_loss : 0.334086
# batch 0 g_loss : 4.018333
# batch 1 d_loss : 0.296308
# batch 1 g_loss : 3.684742
# batch 2 d_loss : 0.338610
# batch 2 g_loss : 3.915912
# batch 3 d_loss : 0.303559
# batch 3 g_loss : 4.265459
# Epoch is 169
# Number of batches 4
# batch 0 d_loss : 0.496874
# batch 0 g_loss : 4.018479
# batch 1 d_loss : 0.216282
# batch 1 g_loss : 4.311014
# batch 2 d_loss : 0.308126
# batch 2 g_loss : 4.555903
# batch 3 d_loss : 0.184505
# batch 3 g_loss : 2.924128
# Epoch is 170
# Number of batches 4
# batch 0 d_loss : 0.273387
# batch 0 g_loss : 3.524699
# batch 1 d_loss : 0.486457
# batch 1 g_loss : 3.833281
# batch 2 d_loss : 0.336141
# batch 2 g_loss : 3.707094
# batch 3 d_loss : 0.405902
# batch 3 g_loss : 3.726152
# Epoch is 171
# Number of batches 4
# batch 0 d_loss : 0.325179
# batch 0 g_loss : 3.942338
# batch 1 d_loss : 0.189112
# batch 1 g_loss : 3.475664
# batch 2 d_loss : 0.335409
# batch 2 g_loss : 4.774514
# batch 3 d_loss : 0.173624
# batch 3 g_loss : 3.561939
# Epoch is 172
# Number of batches 4
# batch 0 d_loss : 0.484933
# batch 0 g_loss : 4.311722
# batch 1 d_loss : 0.304809
# batch 1 g_loss : 3.848625
# batch 2 d_loss : 0.191112
# batch 2 g_loss : 3.584665
# batch 3 d_loss : 0.298270
# batch 3 g_loss : 3.436044
# Epoch is 173
# Number of batches 4
# batch 0 d_loss : 0.286993
# batch 0 g_loss : 3.285220
# batch 1 d_loss : 0.415105
# batch 1 g_loss : 4.272552
# batch 2 d_loss : 0.227728
# batch 2 g_loss : 4.321574
# batch 3 d_loss : 0.166087
# batch 3 g_loss : 3.753866
# Epoch is 174
# Number of batches 4
# batch 0 d_loss : 0.278501
# batch 0 g_loss : 4.092378
# batch 1 d_loss : 0.378687
# batch 1 g_loss : 4.189449
# batch 2 d_loss : 0.538681
# batch 2 g_loss : 3.340930
# batch 3 d_loss : 0.221042
# batch 3 g_loss : 4.266152
# Epoch is 175
# Number of batches 4
# batch 0 d_loss : 0.340191
# batch 0 g_loss : 3.255570
# batch 1 d_loss : 0.222108
# batch 1 g_loss : 4.361165
# batch 2 d_loss : 0.238588
# batch 2 g_loss : 3.974718
# batch 3 d_loss : 0.181975
# batch 3 g_loss : 3.982660
# Epoch is 176
# Number of batches 4
# batch 0 d_loss : 0.241027
# batch 0 g_loss : 3.772355
# batch 1 d_loss : 0.430136
# batch 1 g_loss : 3.846985
# batch 2 d_loss : 0.321374
# batch 2 g_loss : 4.177417
# batch 3 d_loss : 0.144699
# batch 3 g_loss : 3.475709
# Epoch is 177
# Number of batches 4
# batch 0 d_loss : 0.239667
# batch 0 g_loss : 3.911324
# batch 1 d_loss : 0.457632
# batch 1 g_loss : 4.042823
# batch 2 d_loss : 0.166688
# batch 2 g_loss : 3.489505
# batch 3 d_loss : 0.179850
# batch 3 g_loss : 3.878051
# Epoch is 178
# Number of batches 4
# batch 0 d_loss : 0.328117
# batch 0 g_loss : 4.961428
# batch 1 d_loss : 0.192180
# batch 1 g_loss : 4.216090
# batch 2 d_loss : 0.367555
# batch 2 g_loss : 4.090978
# batch 3 d_loss : 0.113330
# batch 3 g_loss : 3.195951
# Epoch is 179
# Number of batches 4
# batch 0 d_loss : 0.195965
# batch 0 g_loss : 4.293606
# batch 1 d_loss : 0.320406
# batch 1 g_loss : 5.213052
# batch 2 d_loss : 0.161429
# batch 2 g_loss : 4.065132
# batch 3 d_loss : 0.309485
# batch 3 g_loss : 4.240020
# Epoch is 180
# Number of batches 4
# batch 0 d_loss : 0.145005
# batch 0 g_loss : 4.110526
# batch 1 d_loss : 0.289951
# batch 1 g_loss : 4.814128
# batch 2 d_loss : 0.161540
# batch 2 g_loss : 3.491790
# batch 3 d_loss : 0.568644
# batch 3 g_loss : 3.857049
# Epoch is 181
# Number of batches 4
# batch 0 d_loss : 0.298587
# batch 0 g_loss : 4.579388
# batch 1 d_loss : 0.470017
# batch 1 g_loss : 4.508007
# batch 2 d_loss : 0.496079
# batch 2 g_loss : 4.780298
# batch 3 d_loss : 0.274346
# batch 3 g_loss : 4.136682
# Epoch is 182
# Number of batches 4
# batch 0 d_loss : 0.170741
# batch 0 g_loss : 4.133591
# batch 1 d_loss : 0.243473
# batch 1 g_loss : 3.908311
# batch 2 d_loss : 0.943006
# batch 2 g_loss : 3.949891
# batch 3 d_loss : 0.264790
# batch 3 g_loss : 4.209222
# Epoch is 183
# Number of batches 4
# batch 0 d_loss : 0.349411
# batch 0 g_loss : 4.334283
# batch 1 d_loss : 0.301450
# batch 1 g_loss : 4.176963
# batch 2 d_loss : 0.445197
# batch 2 g_loss : 3.991813
# batch 3 d_loss : 0.481826
# batch 3 g_loss : 3.468606
# Epoch is 184
# Number of batches 4
# batch 0 d_loss : 0.333928
# batch 0 g_loss : 3.974116
# batch 1 d_loss : 0.190835
# batch 1 g_loss : 3.771694
# batch 2 d_loss : 0.229277
# batch 2 g_loss : 3.437852
# batch 3 d_loss : 0.415666
# batch 3 g_loss : 4.080065
# Epoch is 185
# Number of batches 4
# batch 0 d_loss : 0.265479
# batch 0 g_loss : 2.514611
# batch 1 d_loss : 0.030431
# batch 1 g_loss : 4.286186
# batch 2 d_loss : 0.332319
# batch 2 g_loss : 3.038239
# batch 3 d_loss : 0.224769
# batch 3 g_loss : 3.681257
# Epoch is 186
# Number of batches 4
# batch 0 d_loss : 0.321935
# batch 0 g_loss : 4.395512
# batch 1 d_loss : 0.027740
# batch 1 g_loss : 3.569853
# batch 2 d_loss : 0.178486
# batch 2 g_loss : 4.281512
# batch 3 d_loss : 0.302581
# batch 3 g_loss : 4.252632
# Epoch is 187
# Number of batches 4
# batch 0 d_loss : 0.122760
# batch 0 g_loss : 3.678649
# batch 1 d_loss : 0.052137
# batch 1 g_loss : 3.883708
# batch 2 d_loss : 0.426092
# batch 2 g_loss : 3.735181
# batch 3 d_loss : 0.170018
# batch 3 g_loss : 3.712845
# Epoch is 188
# Number of batches 4
# batch 0 d_loss : 0.159944
# batch 0 g_loss : 3.299686
# batch 1 d_loss : 0.148340
# batch 1 g_loss : 3.327577
# batch 2 d_loss : 0.207927
# batch 2 g_loss : 2.803793
# batch 3 d_loss : 0.396953
# batch 3 g_loss : 3.663643
# Epoch is 189
# Number of batches 4
# batch 0 d_loss : 0.253344
# batch 0 g_loss : 3.615053
# batch 1 d_loss : 0.047494
# batch 1 g_loss : 3.705605
# batch 2 d_loss : 0.283250
# batch 2 g_loss : 3.701334
# batch 3 d_loss : 0.311154
# batch 3 g_loss : 3.406551
# Epoch is 190
# Number of batches 4
# batch 0 d_loss : 0.203459
# batch 0 g_loss : 3.304143
# batch 1 d_loss : 0.256874
# batch 1 g_loss : 3.112467
# batch 2 d_loss : 0.381572
# batch 2 g_loss : 3.730411
# batch 3 d_loss : 0.321418
# batch 3 g_loss : 3.781637
# Epoch is 191
# Number of batches 4
# batch 0 d_loss : 0.470512
# batch 0 g_loss : 3.533896
# batch 1 d_loss : 0.246642
# batch 1 g_loss : 4.158207
# batch 2 d_loss : 0.377066
# batch 2 g_loss : 4.311347
# batch 3 d_loss : 0.426284
# batch 3 g_loss : 3.357562
# Epoch is 192
# Number of batches 4
# batch 0 d_loss : 0.620637
# batch 0 g_loss : 3.447487
# batch 1 d_loss : 0.480856
# batch 1 g_loss : 3.505075
# batch 2 d_loss : 0.398640
# batch 2 g_loss : 4.311681
# batch 3 d_loss : 0.278831
# batch 3 g_loss : 3.611523
# Epoch is 193
# Number of batches 4
# batch 0 d_loss : 0.317305
# batch 0 g_loss : 2.993663
# batch 1 d_loss : 0.204839
# batch 1 g_loss : 3.643755
# batch 2 d_loss : 0.192791
# batch 2 g_loss : 2.919374
# batch 3 d_loss : 0.185338
# batch 3 g_loss : 3.600405
# Epoch is 194
# Number of batches 4
# batch 0 d_loss : 0.135801
# batch 0 g_loss : 3.660947
# batch 1 d_loss : 0.287972
# batch 1 g_loss : 3.432961
# batch 2 d_loss : 0.146071
# batch 2 g_loss : 2.519947
# batch 3 d_loss : 0.349660
# batch 3 g_loss : 3.614319
# Epoch is 195
# Number of batches 4
# batch 0 d_loss : 0.322908
# batch 0 g_loss : 4.390797
# batch 1 d_loss : 0.195695
# batch 1 g_loss : 4.689747
# batch 2 d_loss : 0.176056
# batch 2 g_loss : 3.398484
# batch 3 d_loss : 0.103826
# batch 3 g_loss : 3.362451
# Epoch is 196
# Number of batches 4
# batch 0 d_loss : 0.410945
# batch 0 g_loss : 2.819800
# batch 1 d_loss : 0.448755
# batch 1 g_loss : 3.425893
# batch 2 d_loss : 0.224653
# batch 2 g_loss : 3.855587
# batch 3 d_loss : 0.140845
# batch 3 g_loss : 3.840437
# Epoch is 197
# Number of batches 4
# batch 0 d_loss : 0.295577
# batch 0 g_loss : 4.850022
# batch 1 d_loss : 0.262876
# batch 1 g_loss : 4.052457
# batch 2 d_loss : 0.194861
# batch 2 g_loss : 3.582597
# batch 3 d_loss : 0.271228
# batch 3 g_loss : 3.345231
# Epoch is 198
# Number of batches 4
# batch 0 d_loss : 0.152845
# batch 0 g_loss : 4.178745
# batch 1 d_loss : 0.258660
# batch 1 g_loss : 3.916052
# batch 2 d_loss : 0.461698
# batch 2 g_loss : 3.949866
# batch 3 d_loss : 0.438097
# batch 3 g_loss : 3.937499
# Epoch is 199
# Number of batches 4
# batch 0 d_loss : 0.405865
# batch 0 g_loss : 4.326003
# batch 1 d_loss : 0.486398
# ...
# batch 2 g_loss : 3.752486
# batch 3 d_loss : 0.281295
# batch 3 g_loss : 2.384404
# Epoch is 334
# Number of batches 4
# batch 0 d_loss : 0.155752
# batch 0 g_loss : 3.044308
# batch 1 d_loss : 0.332954
# batch 1 g_loss : 1.503378
# batch 2 d_loss : 0.204838
# batch 2 g_loss : 2.604311
# batch 3 d_loss : 0.219524
# batch 3 g_loss : 2.054928
# Epoch is 335
# Number of batches 4
# batch 0 d_loss : 0.209435
# batch 0 g_loss : 3.408798
# batch 1 d_loss : 0.224439
# batch 1 g_loss : 3.228628
# batch 2 d_loss : 0.113480
# batch 2 g_loss : 3.120215
# batch 3 d_loss : 0.284532
# batch 3 g_loss : 3.120647
# Epoch is 336
# Number of batches 4
# batch 0 d_loss : 0.249691
# batch 0 g_loss : 3.279756
# batch 1 d_loss : 0.166129
# batch 1 g_loss : 2.396528
# batch 2 d_loss : 0.131988
# batch 2 g_loss : 1.467552
# batch 3 d_loss : 0.176908
# batch 3 g_loss : 1.931856
# Epoch is 337
# Number of batches 4
# batch 0 d_loss : 0.312423
# batch 0 g_loss : 1.454064
# batch 1 d_loss : 0.248493
# batch 1 g_loss : 2.285471
# batch 2 d_loss : 0.130838
# batch 2 g_loss : 3.040395
# batch 3 d_loss : 0.226977
# batch 3 g_loss : 3.418544
# Epoch is 338
# Number of batches 4
# batch 0 d_loss : 0.315235
# batch 0 g_loss : 3.012826
# batch 1 d_loss : 0.203759
# batch 1 g_loss : 1.597232
# batch 2 d_loss : 0.080660
# batch 2 g_loss : 1.580533
# batch 3 d_loss : 0.129208
# batch 3 g_loss : 1.036970
# Epoch is 339
# Number of batches 4
# batch 0 d_loss : 0.244565
# batch 0 g_loss : 1.950650
# batch 1 d_loss : 0.170836
# batch 1 g_loss : 1.881969
# batch 2 d_loss : 0.355488
# batch 2 g_loss : 1.433483
# batch 3 d_loss : 0.229086
# batch 3 g_loss : 1.550595
# Epoch is 340
# Number of batches 4
# batch 0 d_loss : 0.155336
# batch 0 g_loss : 2.831435
# batch 1 d_loss : 0.135677
# batch 1 g_loss : 2.157504
# batch 2 d_loss : 0.183687
# batch 2 g_loss : 3.524970
# batch 3 d_loss : 0.260203
# batch 3 g_loss : 2.871298
# Epoch is 341
# Number of batches 4
# batch 0 d_loss : 0.194200
# batch 0 g_loss : 2.664493
# batch 1 d_loss : 0.183845
# batch 1 g_loss : 3.554593
# batch 2 d_loss : 0.136010
# batch 2 g_loss : 3.088907
# batch 3 d_loss : 0.196331
# batch 3 g_loss : 2.469846
# Epoch is 342
# Number of batches 4
# batch 0 d_loss : 0.172870
# batch 0 g_loss : 1.932556
# batch 1 d_loss : 0.146574
# batch 1 g_loss : 2.287288
# batch 2 d_loss : 0.155091
# batch 2 g_loss : 1.546509
# batch 3 d_loss : 0.188412
# batch 3 g_loss : 2.625020
# Epoch is 343
# Number of batches 4
# batch 0 d_loss : 0.188674
# batch 0 g_loss : 1.730303
# batch 1 d_loss : 0.109477
# batch 1 g_loss : 2.184309
# batch 2 d_loss : 0.142737
# batch 2 g_loss : 2.200296
# batch 3 d_loss : 0.167144
# batch 3 g_loss : 2.521453
# Epoch is 344
# Number of batches 4
# batch 0 d_loss : 0.199198
# batch 0 g_loss : 2.047285
# batch 1 d_loss : 0.176665
# batch 1 g_loss : 3.374058
# batch 2 d_loss : 0.160978
# batch 2 g_loss : 2.822372
# batch 3 d_loss : 0.149825
# batch 3 g_loss : 2.274484
# Epoch is 345
# Number of batches 4
# batch 0 d_loss : 0.156885
# batch 0 g_loss : 2.046467
# batch 1 d_loss : 0.113469
# batch 1 g_loss : 1.727118
# batch 2 d_loss : 0.122747
# batch 2 g_loss : 2.692978
# batch 3 d_loss : 0.249755
# batch 3 g_loss : 2.572021
# Epoch is 346
# Number of batches 4
# batch 0 d_loss : 0.127013
# batch 0 g_loss : 2.804336
# batch 1 d_loss : 0.246983
# batch 1 g_loss : 2.522305
# batch 2 d_loss : 0.186405
# batch 2 g_loss : 2.731899
# batch 3 d_loss : 0.234570
# batch 3 g_loss : 2.254878
# Epoch is 347
# Number of batches 4
# batch 0 d_loss : 0.232150
# batch 0 g_loss : 1.471827
# batch 1 d_loss : 0.205683
# batch 1 g_loss : 3.355462
# batch 2 d_loss : 0.317963
# batch 2 g_loss : 3.261145
# batch 3 d_loss : 0.205811
# batch 3 g_loss : 3.455460
# Epoch is 348
# Number of batches 4
# batch 0 d_loss : 0.193500
# batch 0 g_loss : 2.903454
# batch 1 d_loss : 0.242516
# batch 1 g_loss : 2.798407
# batch 2 d_loss : 0.228883
# batch 2 g_loss : 2.891093
# batch 3 d_loss : 0.208654
# batch 3 g_loss : 2.692740
# Epoch is 349
# Number of batches 4
# batch 0 d_loss : 0.106939
# batch 0 g_loss : 2.100296
# batch 1 d_loss : 0.164573
# batch 1 g_loss : 1.892231
# batch 2 d_loss : 0.126207
# batch 2 g_loss : 2.987322
# batch 3 d_loss : 0.112954
# batch 3 g_loss : 1.950939
# Epoch is 350
# Number of batches 4
# batch 0 d_loss : 0.200461
# batch 0 g_loss : 2.278893
# batch 1 d_loss : 0.157893
# batch 1 g_loss : 2.973181
# batch 2 d_loss : 0.157900
# batch 2 g_loss : 3.244933
# batch 3 d_loss : 0.324244
# batch 3 g_loss : 2.781218
# Epoch is 351
# Number of batches 4
# batch 0 d_loss : 0.182032
# batch 0 g_loss : 3.115725
# batch 1 d_loss : 0.098192
# batch 1 g_loss : 2.522566
# batch 2 d_loss : 0.122911
# batch 2 g_loss : 1.692492
# batch 3 d_loss : 0.171806
# batch 3 g_loss : 2.682091
# Epoch is 352
# Number of batches 4
# batch 0 d_loss : 0.150069
# batch 0 g_loss : 3.579701
# batch 1 d_loss : 0.127301
# batch 1 g_loss : 3.173203
# batch 2 d_loss : 0.150858
# batch 2 g_loss : 2.731879
# batch 3 d_loss : 0.195966
# batch 3 g_loss : 3.272955
# Epoch is 353
# Number of batches 4
# batch 0 d_loss : 0.110274
# batch 0 g_loss : 4.655869
# batch 1 d_loss : 0.171338
# batch 1 g_loss : 2.062750
# batch 2 d_loss : 0.132213
# batch 2 g_loss : 1.463604
# batch 3 d_loss : 0.132584
# batch 3 g_loss : 1.831774
# Epoch is 354
# Number of batches 4
# batch 0 d_loss : 0.151064
# batch 0 g_loss : 2.240270
# batch 1 d_loss : 0.142269
# batch 1 g_loss : 2.834975
# batch 2 d_loss : 0.137583
# batch 2 g_loss : 3.530952
# batch 3 d_loss : 0.174427
# batch 3 g_loss : 3.190488
# Epoch is 355
# Number of batches 4
# batch 0 d_loss : 0.109690
# batch 0 g_loss : 2.465917
# batch 1 d_loss : 0.096038
# batch 1 g_loss : 2.453867
# batch 2 d_loss : 0.123831
# batch 2 g_loss : 2.220678
# batch 3 d_loss : 0.146366
# batch 3 g_loss : 2.719030
# Epoch is 356
# Number of batches 4
# batch 0 d_loss : 0.078559
# batch 0 g_loss : 3.273360
# batch 1 d_loss : 0.067455
# batch 1 g_loss : 3.065037
# batch 2 d_loss : 0.133715
# batch 2 g_loss : 2.614473
# batch 3 d_loss : 0.100485
# batch 3 g_loss : 2.348381
# Epoch is 357
# Number of batches 4
# batch 0 d_loss : 0.079959
# batch 0 g_loss : 2.560852
# batch 1 d_loss : 0.061177
# batch 1 g_loss : 2.715362
# batch 2 d_loss : 0.110119
# batch 2 g_loss : 2.605936
# batch 3 d_loss : 0.096612
# batch 3 g_loss : 2.917045
# Epoch is 358
# Number of batches 4
# batch 0 d_loss : 0.139549
# batch 0 g_loss : 3.830690
# batch 1 d_loss : 0.080129
# batch 1 g_loss : 2.908641
# batch 2 d_loss : 0.141379
# batch 2 g_loss : 2.758928
# batch 3 d_loss : 0.149852
# batch 3 g_loss : 2.278322
# Epoch is 359
# Number of batches 4
# batch 0 d_loss : 0.116559
# batch 0 g_loss : 2.061075
# batch 1 d_loss : 0.091638
# batch 1 g_loss : 1.751108
# batch 2 d_loss : 0.159156
# batch 2 g_loss : 2.203983
# batch 3 d_loss : 0.140623
# batch 3 g_loss : 2.705269
# Epoch is 360
# Number of batches 4
# batch 0 d_loss : 0.209729
# batch 0 g_loss : 3.072960
# batch 1 d_loss : 0.111818
# batch 1 g_loss : 3.876206
# batch 2 d_loss : 0.102086
# batch 2 g_loss : 2.737745
# batch 3 d_loss : 0.102524
# batch 3 g_loss : 2.505989
# Epoch is 361
# Number of batches 4
# batch 0 d_loss : 0.082712
# batch 0 g_loss : 2.195446
# batch 1 d_loss : 0.197977
# batch 1 g_loss : 2.321963
# batch 2 d_loss : 0.113830
# batch 2 g_loss : 2.597765
# batch 3 d_loss : 0.152469
# batch 3 g_loss : 2.927489
# Epoch is 362
# Number of batches 4
# batch 0 d_loss : 0.117141
# batch 0 g_loss : 2.299905
# batch 1 d_loss : 0.091663
# batch 1 g_loss : 2.606942
# batch 2 d_loss : 0.190039
# batch 2 g_loss : 2.724564
# batch 3 d_loss : 0.131838
# batch 3 g_loss : 2.405637
# Epoch is 363
# Number of batches 4
# batch 0 d_loss : 0.116490
# batch 0 g_loss : 2.662757
# batch 1 d_loss : 0.130466
# batch 1 g_loss : 2.365261
# batch 2 d_loss : 0.125630
# batch 2 g_loss : 1.818088
# batch 3 d_loss : 0.239734
# batch 3 g_loss : 2.240460
# Epoch is 364
# Number of batches 4
# batch 0 d_loss : 0.108361
# batch 0 g_loss : 2.501293
# batch 1 d_loss : 0.093643
# batch 1 g_loss : 2.097954
# batch 2 d_loss : 0.169122
# batch 2 g_loss : 3.483018
# batch 3 d_loss : 0.156757
# batch 3 g_loss : 2.281923
# Epoch is 365
# Number of batches 4
# batch 0 d_loss : 0.131793
# batch 0 g_loss : 2.015912
# batch 1 d_loss : 0.107017
# batch 1 g_loss : 2.405156
# batch 2 d_loss : 0.107104
# batch 2 g_loss : 2.280217
# batch 3 d_loss : 0.203662
# batch 3 g_loss : 2.756515
# Epoch is 366
# Number of batches 4
# batch 0 d_loss : 0.087646
# batch 0 g_loss : 2.318664
# batch 1 d_loss : 0.180446
# batch 1 g_loss : 2.896416
# batch 2 d_loss : 0.145725
# batch 2 g_loss : 2.724192
# batch 3 d_loss : 0.118721
# batch 3 g_loss : 2.039965
# Epoch is 367
# Number of batches 4
# batch 0 d_loss : 0.210572
# batch 0 g_loss : 2.295063
# batch 1 d_loss : 0.146457
# batch 1 g_loss : 3.059978
# batch 2 d_loss : 0.145601
# batch 2 g_loss : 2.905334
# batch 3 d_loss : 0.133508
# batch 3 g_loss : 3.195733
# Epoch is 368
# Number of batches 4
# batch 0 d_loss : 0.156326
# batch 0 g_loss : 3.107333
# batch 1 d_loss : 0.115672
# batch 1 g_loss : 2.439232
# batch 2 d_loss : 0.109343
# batch 2 g_loss : 2.871566
# batch 3 d_loss : 0.136659
# batch 3 g_loss : 2.621739
# Epoch is 369
# Number of batches 4
# batch 0 d_loss : 0.130144
# batch 0 g_loss : 3.010764
# batch 1 d_loss : 0.178659
# batch 1 g_loss : 2.786435
# batch 2 d_loss : 0.108464
# batch 2 g_loss : 2.704973
# batch 3 d_loss : 0.118706
# batch 3 g_loss : 2.394538
# Epoch is 370
# Number of batches 4
# batch 0 d_loss : 0.113114
# batch 0 g_loss : 3.123515
# batch 1 d_loss : 0.098243
# batch 1 g_loss : 2.971411
# batch 2 d_loss : 0.157346
# batch 2 g_loss : 2.607893
# batch 3 d_loss : 0.105790
# batch 3 g_loss : 2.439362
# Epoch is 371
# Number of batches 4
# batch 0 d_loss : 0.094550
# batch 0 g_loss : 2.836675
# batch 1 d_loss : 0.111475
# batch 1 g_loss : 2.656840
# batch 2 d_loss : 0.118822
# batch 2 g_loss : 1.803309
# batch 3 d_loss : 0.118476
# batch 3 g_loss : 3.227229
# Epoch is 372
# Number of batches 4
# batch 0 d_loss : 0.101930
# batch 0 g_loss : 3.690570
# batch 1 d_loss : 0.068714
# batch 1 g_loss : 3.126842
# batch 2 d_loss : 0.104487
# batch 2 g_loss : 2.723175
# batch 3 d_loss : 0.150528
# batch 3 g_loss : 2.752771
# Epoch is 373
# Number of batches 4
# batch 0 d_loss : 0.113804
# batch 0 g_loss : 2.310606
# batch 1 d_loss : 0.097176
# batch 1 g_loss : 2.782562
# batch 2 d_loss : 0.103609
# batch 2 g_loss : 2.241604
# batch 3 d_loss : 0.163886
# batch 3 g_loss : 3.730379
# Epoch is 374
# Number of batches 4
# batch 0 d_loss : 0.162976
# batch 0 g_loss : 2.266123
# batch 1 d_loss : 0.093675
# batch 1 g_loss : 2.848830
# batch 2 d_loss : 0.163928
# batch 2 g_loss : 3.845151
# batch 3 d_loss : 0.186697
# batch 3 g_loss : 2.869589
# Epoch is 375
# Number of batches 4
# batch 0 d_loss : 0.159011
# batch 0 g_loss : 2.503158
# batch 1 d_loss : 0.145813
# batch 1 g_loss : 2.729037
# batch 2 d_loss : 0.092323
# batch 2 g_loss : 2.865880
# batch 3 d_loss : 0.199217
# batch 3 g_loss : 3.410687
# Epoch is 376
# Number of batches 4
# batch 0 d_loss : 0.123546
# batch 0 g_loss : 3.038733
# batch 1 d_loss : 0.083691
# batch 1 g_loss : 2.713086
# batch 2 d_loss : 0.150672
# batch 2 g_loss : 3.286142
# batch 3 d_loss : 0.181304
# batch 3 g_loss : 2.028232
# Epoch is 377
# Number of batches 4
# batch 0 d_loss : 0.068145
# batch 0 g_loss : 2.109414
# batch 1 d_loss : 0.162100
# batch 1 g_loss : 2.673161
# batch 2 d_loss : 0.197400
# batch 2 g_loss : 3.023969
# batch 3 d_loss : 0.134904
# batch 3 g_loss : 3.544923
# Epoch is 378
# Number of batches 4
# batch 0 d_loss : 0.089361
# batch 0 g_loss : 3.351003
# batch 1 d_loss : 0.122686
# batch 1 g_loss : 3.587994
# batch 2 d_loss : 0.122861
# batch 2 g_loss : 3.338722
# batch 3 d_loss : 0.176863
# batch 3 g_loss : 3.006019
# Epoch is 379
# Number of batches 4
# batch 0 d_loss : 0.074990
# batch 0 g_loss : 2.259862
# batch 1 d_loss : 0.065841
# batch 1 g_loss : 2.363133
# batch 2 d_loss : 0.199560
# batch 2 g_loss : 1.590609
# batch 3 d_loss : 0.116328
# batch 3 g_loss : 3.908195
# Epoch is 380
# Number of batches 4
# batch 0 d_loss : 0.083515
# batch 0 g_loss : 2.505076
# batch 1 d_loss : 0.096795
# batch 1 g_loss : 2.392200
# batch 2 d_loss : 0.099483
# batch 2 g_loss : 4.683547
# batch 3 d_loss : 0.193027
# batch 3 g_loss : 3.068353
# Epoch is 381
# Number of batches 4
# batch 0 d_loss : 0.119863
# batch 0 g_loss : 2.743463
# batch 1 d_loss : 0.059355
# batch 1 g_loss : 1.563136
# batch 2 d_loss : 0.105311
# batch 2 g_loss : 2.782879
# batch 3 d_loss : 0.132947
# batch 3 g_loss : 2.184810
# Epoch is 382
# Number of batches 4
# batch 0 d_loss : 0.205381
# batch 0 g_loss : 2.737172
# batch 1 d_loss : 0.074864
# batch 1 g_loss : 2.195110
# batch 2 d_loss : 0.161627
# batch 2 g_loss : 3.019074
# batch 3 d_loss : 0.194649
# batch 3 g_loss : 2.911910
# Epoch is 383
# Number of batches 4
# batch 0 d_loss : 0.125433
# batch 0 g_loss : 4.927642
# batch 1 d_loss : 0.136399
# batch 1 g_loss : 3.725057
# batch 2 d_loss : 0.113425
# batch 2 g_loss : 3.233144
# batch 3 d_loss : 0.130848
# batch 3 g_loss : 2.580430
# Epoch is 384
# Number of batches 4
# batch 0 d_loss : 0.141463
# batch 0 g_loss : 2.316061
# batch 1 d_loss : 0.138949
# batch 1 g_loss : 3.039081
# batch 2 d_loss : 0.103131
# batch 2 g_loss : 1.954334
# batch 3 d_loss : 0.160207
# batch 3 g_loss : 2.831611
# Epoch is 385
# Number of batches 4
# batch 0 d_loss : 0.100612
# batch 0 g_loss : 2.850555
# batch 1 d_loss : 0.092637
# batch 1 g_loss : 2.998896
# batch 2 d_loss : 0.066993
# batch 2 g_loss : 3.344924
# batch 3 d_loss : 0.158216
# batch 3 g_loss : 3.482172
# Epoch is 386
# Number of batches 4
# batch 0 d_loss : 0.078125
# batch 0 g_loss : 3.505451
# batch 1 d_loss : 0.089811
# batch 1 g_loss : 3.240228
# batch 2 d_loss : 0.075658
# batch 2 g_loss : 2.741930
# batch 3 d_loss : 0.111419
# batch 3 g_loss : 2.633697
# Epoch is 387
# Number of batches 4
# batch 0 d_loss : 0.064180
# batch 0 g_loss : 3.246472
# batch 1 d_loss : 0.100273
# batch 1 g_loss : 2.332027
# batch 2 d_loss : 0.152633
# batch 2 g_loss : 2.303454
# batch 3 d_loss : 0.122058
# batch 3 g_loss : 3.602638
# Epoch is 388
# Number of batches 4
# batch 0 d_loss : 0.104921
# batch 0 g_loss : 2.919648
# batch 1 d_loss : 0.120371
# batch 1 g_loss : 2.878791
# batch 2 d_loss : 0.104150
# batch 2 g_loss : 3.478192
# batch 3 d_loss : 0.128400
# batch 3 g_loss : 3.179452
# Epoch is 389
# Number of batches 4
# batch 0 d_loss : 0.101734
# batch 0 g_loss : 2.047891
# batch 1 d_loss : 0.100307
# batch 1 g_loss : 2.394913
# batch 2 d_loss : 0.068233
# batch 2 g_loss : 2.717476
# batch 3 d_loss : 0.128549
# batch 3 g_loss : 2.699011
# Epoch is 390
# Number of batches 4
# batch 0 d_loss : 0.106464
# batch 0 g_loss : 2.686097
# batch 1 d_loss : 0.075224
# batch 1 g_loss : 4.284959
# batch 2 d_loss : 0.058757
# batch 2 g_loss : 3.673850
# batch 3 d_loss : 0.143022
# batch 3 g_loss : 3.519101
# Epoch is 391
# Number of batches 4
# batch 0 d_loss : 0.076228
# batch 0 g_loss : 4.166221
# batch 1 d_loss : 0.051531
# batch 1 g_loss : 2.238358
# batch 2 d_loss : 0.118820
# batch 2 g_loss : 3.029989
# batch 3 d_loss : 0.081921
# batch 3 g_loss : 2.783825
# Epoch is 392
# Number of batches 4
# batch 0 d_loss : 0.079401
# batch 0 g_loss : 2.464112
# batch 1 d_loss : 0.086254
# batch 1 g_loss : 2.840706
# batch 2 d_loss : 0.059325
# batch 2 g_loss : 3.448012
# batch 3 d_loss : 0.099347
# batch 3 g_loss : 3.360235
# Epoch is 393
# Number of batches 4
# batch 0 d_loss : 0.082891
# batch 0 g_loss : 3.132384
# batch 1 d_loss : 0.113316
# batch 1 g_loss : 3.670576
# batch 2 d_loss : 0.067359
# batch 2 g_loss : 4.538537
# batch 3 d_loss : 0.109175
# batch 3 g_loss : 3.020816
# Epoch is 394
# Number of batches 4
# batch 0 d_loss : 0.069499
# batch 0 g_loss : 2.728324
# batch 1 d_loss : 0.086835
# batch 1 g_loss : 2.682870
# batch 2 d_loss : 0.101643
# batch 2 g_loss : 2.190826
# batch 3 d_loss : 0.106553
# batch 3 g_loss : 4.108187
# Epoch is 395
# Number of batches 4
# batch 0 d_loss : 0.134322
# batch 0 g_loss : 3.806688
# batch 1 d_loss : 0.093547
# batch 1 g_loss : 3.893486
# batch 2 d_loss : 0.058906
# batch 2 g_loss : 4.308656
# batch 3 d_loss : 0.215984
# batch 3 g_loss : 3.064077
# Epoch is 396
# Number of batches 4
# batch 0 d_loss : 0.088142
# batch 0 g_loss : 3.373836
# batch 1 d_loss : 0.085564
# batch 1 g_loss : 2.823900
# batch 2 d_loss : 0.090013
# batch 2 g_loss : 2.747353
# batch 3 d_loss : 0.104407
# batch 3 g_loss : 2.394832
# Epoch is 397
# Number of batches 4
# batch 0 d_loss : 0.099524
# batch 0 g_loss : 2.631087
# batch 1 d_loss : 0.106006
# batch 1 g_loss : 3.321502
# batch 2 d_loss : 0.097322
# batch 2 g_loss : 4.064619
# batch 3 d_loss : 0.116140
# batch 3 g_loss : 3.761389
# Epoch is 398
# Number of batches 4
# batch 0 d_loss : 0.079924
# batch 0 g_loss : 3.224326
# batch 1 d_loss : 0.104549
# batch 1 g_loss : 3.325291
# batch 2 d_loss : 0.073256
# batch 2 g_loss : 3.061802
# batch 3 d_loss : 0.089557
# batch 3 g_loss : 2.758780
# Epoch is 399
# Number of batches 4
# batch 0 d_loss : 0.106141
# batch 0 g_loss : 3.899218
# batch 1 d_loss : 0.172674
# batch 1 g_loss : 3.063415
# batch 2 d_loss : 0.081326
# batch 2 g_loss : 2.997382
# batch 3 d_loss : 0.091204
# batch 3 g_loss : 3.161141

# %%
generate(1)
# Out:
# 1/1 [==============================] - 0s
# (1, 1, 128, 128)
